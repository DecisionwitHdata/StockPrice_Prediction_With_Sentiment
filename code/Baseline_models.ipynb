# %% [markdown]
# ## Stock Prediction Notebook(Baseline)
# This notebook demonstrates stock price prediction using data without sentiment analysis. It covers data preparation, model definition, training, and evaluation.

# %%
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import requests
import zipfile
import os
from io import BytesIO

# %% [markdown]
# ### Data Preparation
# Classes and functions for loading and preprocessing data.

# %%
# Loading data section
# ZIP file URL from GitHub repository
url = 'https://github.com/yumoxu/stocknet-dataset/archive/refs/heads/master.zip'

# Download ZIP file and read into memory
response = requests.get(url)
zip_file = zipfile.ZipFile(BytesIO(response.content))

# Folder path for 'stocknet-dataset-master/price/raw/' in ZIP file
price_folder_path = 'stocknet-dataset-master/price/raw/'

# Read and combine all CSV files
data_frames = []
for file_name in zip_file.namelist():
    if file_name.startswith(price_folder_path) and file_name.endswith('.csv'):
        # Extract stock name from filename (e.g., 'raw/prices/appl.csv' -> 'appl')
        stock_name = os.path.splitext(os.path.basename(file_name))[0]

        # Read CSV file and convert to DataFrame
        with zip_file.open(file_name) as file:
            df = pd.read_csv(file)
             # Add stock name column
            df['Stock'] = stock_name
            df['Date'] = pd.to_datetime(df['Date'])
            # df.set_index('Date', inplace=True)
            data_frames.append(df)

# Combine all DataFrames into one
combined_df = pd.concat(data_frames, ignore_index=False)

# Check the combined DataFrame
print(combined_df.head())
# Out:
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2012-09-04  95.108574  96.448570  94.928574  96.424286  87.121140
# 1 2012-09-05  96.510002  96.621429  95.657143  95.747147  86.509338
# 2 2012-09-06  96.167145  96.898575  95.828575  96.610001  87.288956
# 3 2012-09-07  96.864288  97.497147  96.538574  97.205711  87.827171
# 4 2012-09-10  97.207146  97.612854  94.585716  94.677139  85.542564
#
#         Volume Stock
# 0   91973000.0  AAPL
# 1   84093800.0  AAPL
# 2   97799100.0  AAPL
# 3   82416600.0  AAPL
# 4  121999500.0  AAPL

# %%
class StockDataset(Dataset):
    def __init__(self, data, seq_length):
        self.data = data
        self.seq_length = seq_length
        self.features = data[['Open', 'High', 'Low', 'Volume', 'Adj Close', 'Close']].values
        self.labels = data['movement'].values

    def __len__(self):
        return len(self.data) - self.seq_length

    def __getitem__(self, idx):
        x = self.features[idx:idx+self.seq_length]
        y = self.labels[idx+self.seq_length]
        return torch.tensor(x, dtype=torch.float32), torch.tensor(y, dtype=torch.long)

# %% [markdown]
# ### Model Definition
# Definitions for stock price prediction models using different approaches.

# %%
class BaseRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(BaseRNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
        
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.rnn(x, h0)
        out = self.fc(out[:, -1, :])
        return out

class BaseLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(BaseLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
        
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# ### Logging Setup and Utilities

# %%
import logging

# Set up logging to save output to a file
logging.basicConfig(filename='model_training_log_baseline.txt', level=logging.INFO)

class ModelHandler:
    def __init__(self, model, criterion, optimizer, num_epochs):
        self.model = model
        self.criterion = criterion
        self.optimizer = optimizer
        self.num_epochs = num_epochs

    def train(self, train_loader, company_id, model_name):
        self.model.train()
        for epoch in range(self.num_epochs):
            total_loss = 0.0
            for inputs, labels in train_loader:
                self.optimizer.zero_grad()
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                loss.backward()
                self.optimizer.step()
                
                total_loss += loss.item()
            
            if (epoch + 1) % 10 == 0:
                log_message = f'Company: {company_id}, Model: {model_name}, Epoch [{epoch+1}/{self.num_epochs}], Loss: {total_loss / len(train_loader):.4f}'
                logging.info(log_message)
                print(log_message)

    def evaluate(self, test_loader, company_id, model_name):
        self.model.eval()
        correct = 0
        total = 0
        tp = tn = fp = fn = 0  # Initialize counters
        with torch.no_grad():
            for inputs, labels in test_loader:
                outputs = self.model(inputs)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                # Calculate TP, TN, FP, FN
                tp += ((predicted == 1) & (labels == 1)).sum().item()
                tn += ((predicted == 0) & (labels == 0)).sum().item()
                fp += ((predicted == 1) & (labels == 0)).sum().item()
                fn += ((predicted == 0) & (labels == 1)).sum().item()

        accuracy = correct / total
        macc = self.calculate_mcc(tp, tn, fp, fn)

        # Log and print TP, TN, FP, FN
        log_message = f'Company: {company_id}, Model: {model_name}, TP: {tp}, TN: {tn}, FP: {fp}, FN: {fn}'
        logging.info(log_message)
        print(log_message)
        return accuracy, macc

    def calculate_mcc(self, tp, tn, fp, fn):
        numerator = (tp * tn) - (fp * fn)
        denominator = ((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) ** 0.5
        if denominator == 0:
            return 0
        else:
            return numerator / denominator

# %%
# Main script
def run_models_on_companies(companies, seq_length, num_epochs):
    company_results = {}
    models = [BaseRNN, BaseLSTM]  # Add more models as needed

  # Dictionary to store cumulative accuracy and macc for each model
    model_metrics = {model_cls.__name__: {'accuracy': 0, 'macc': 0, 'count': 0} for model_cls in models}


    for company_id in companies:
        data = filtered[filtered['Stock'] == company_id]
        
        # Train and test split
        train_data = data[(data['Date'] >= '2014-01-01') & (data['Date'] < '2015-10-01')]
        test_data = data[(data['Date'] >= '2015-10-01') & (data['Date'] < '2016-01-01')]
        
        train_dataset = StockDataset(train_data, seq_length)
        test_dataset = StockDataset(test_data, seq_length)

        train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False)
        test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

        for model_cls in models:
            # Instantiate model, criterion, and optimizer
            model = model_cls(input_size=6, hidden_size=32, output_size=2, num_layers=1)
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=0.001)

            handler = ModelHandler(model, criterion, optimizer, num_epochs)
            
            # Pass the company_id and model_name when calling train and evaluate
            handler.train(train_loader, company_id, model_cls.__name__)
            accuracy, macc = handler.evaluate(test_loader, company_id, model_cls.__name__)

            model_name = model_cls.__name__
            company_results[(company_id, model_name)] = {'Accuracy': accuracy, 'MACC': macc}

    # Add accuracy and macc to the cumulative sum for the model
            model_metrics[model_name]['accuracy'] += accuracy
            model_metrics[model_name]['macc'] += macc
            model_metrics[model_name]['count'] += 1  # Track number of companies processed

    # Calculate average accuracy and macc for each model
    avg_results = {}
    for model_name, metrics in model_metrics.items():
        avg_accuracy = metrics['accuracy'] / metrics['count']
        avg_macc = metrics['macc'] / metrics['count']
        avg_results[model_name] = {'Average Accuracy': avg_accuracy, 'Average MACC': avg_macc}
    
    # Save results of all companies
    results_df = pd.DataFrame.from_dict(company_results, orient='index')
    results_df.to_csv('company88_PriceBase_result.csv')

    # Save average results of models
    avg_results_df = pd.DataFrame.from_dict(avg_results, orient='index')
    avg_results_df.to_csv('average_PriceBase_result.csv')

    print("Evaluation complete")
    print(avg_results_df)


# Load the filtered dataset
filtered = pd.read_csv('data/processed/price_scaled.csv')
companies = filtered['Stock'].unique().tolist()

# Run the models
run_models_on_companies(companies, seq_length=5, num_epochs=120)
# Out:
# Company: AAPL, Model: BaseRNN, Epoch [10/120], Loss: 0.6875
# Company: AAPL, Model: BaseRNN, Epoch [20/120], Loss: 0.6868
# Company: AAPL, Model: BaseRNN, Epoch [30/120], Loss: 0.6860
# Company: AAPL, Model: BaseRNN, Epoch [40/120], Loss: 0.6852
# Company: AAPL, Model: BaseRNN, Epoch [50/120], Loss: 0.6843
# Company: AAPL, Model: BaseRNN, Epoch [60/120], Loss: 0.6831
# Company: AAPL, Model: BaseRNN, Epoch [70/120], Loss: 0.6816
# Company: AAPL, Model: BaseRNN, Epoch [80/120], Loss: 0.6807
# Company: AAPL, Model: BaseRNN, Epoch [90/120], Loss: 0.6800
# Company: AAPL, Model: BaseRNN, Epoch [100/120], Loss: 0.6795
# Company: AAPL, Model: BaseRNN, Epoch [110/120], Loss: 0.6789
# Company: AAPL, Model: BaseRNN, Epoch [120/120], Loss: 0.6784
# Company: AAPL, Model: BaseRNN, TP: 15, TN: 20, FP: 15, FN: 9
# Company: AAPL, Model: BaseLSTM, Epoch [10/120], Loss: 0.6872
# Company: AAPL, Model: BaseLSTM, Epoch [20/120], Loss: 0.6860
# Company: AAPL, Model: BaseLSTM, Epoch [30/120], Loss: 0.6850
# Company: AAPL, Model: BaseLSTM, Epoch [40/120], Loss: 0.6843
# Company: AAPL, Model: BaseLSTM, Epoch [50/120], Loss: 0.6837
# Company: AAPL, Model: BaseLSTM, Epoch [60/120], Loss: 0.6833
# Company: AAPL, Model: BaseLSTM, Epoch [70/120], Loss: 0.6830
# Company: AAPL, Model: BaseLSTM, Epoch [80/120], Loss: 0.6828
# Company: AAPL, Model: BaseLSTM, Epoch [90/120], Loss: 0.6825
# Company: AAPL, Model: BaseLSTM, Epoch [100/120], Loss: 0.6823
# Company: AAPL, Model: BaseLSTM, Epoch [110/120], Loss: 0.6821
# Company: AAPL, Model: BaseLSTM, Epoch [120/120], Loss: 0.6819
# Company: AAPL, Model: BaseLSTM, TP: 15, TN: 19, FP: 16, FN: 9
# Company: ABB, Model: BaseRNN, Epoch [10/120], Loss: 0.6870
# Company: ABB, Model: BaseRNN, Epoch [20/120], Loss: 0.6764
# Company: ABB, Model: BaseRNN, Epoch [30/120], Loss: 0.6712
# Company: ABB, Model: BaseRNN, Epoch [40/120], Loss: 0.6701
# Company: ABB, Model: BaseRNN, Epoch [50/120], Loss: 0.6694
# Company: ABB, Model: BaseRNN, Epoch [60/120], Loss: 0.6688
# Company: ABB, Model: BaseRNN, Epoch [70/120], Loss: 0.6683
# Company: ABB, Model: BaseRNN, Epoch [80/120], Loss: 0.6677
# Company: ABB, Model: BaseRNN, Epoch [90/120], Loss: 0.6672
# Company: ABB, Model: BaseRNN, Epoch [100/120], Loss: 0.6667
# Company: ABB, Model: BaseRNN, Epoch [110/120], Loss: 0.6662
# Company: ABB, Model: BaseRNN, Epoch [120/120], Loss: 0.6657
# Company: ABB, Model: BaseRNN, TP: 12, TN: 23, FP: 4, FN: 20
# Company: ABB, Model: BaseLSTM, Epoch [10/120], Loss: 0.6883
# Company: AGFS, Model: BaseLSTM, Epoch [50/120], Loss: 0.6550
# Company: AGFS, Model: BaseLSTM, Epoch [60/120], Loss: 0.6465
# Company: AGFS, Model: BaseLSTM, Epoch [70/120], Loss: 0.6396
# Company: AGFS, Model: BaseLSTM, Epoch [80/120], Loss: 0.6328
# Company: AGFS, Model: BaseLSTM, Epoch [90/120], Loss: 0.6287
# Company: AGFS, Model: BaseLSTM, Epoch [100/120], Loss: 0.6252
# Company: AGFS, Model: BaseLSTM, Epoch [110/120], Loss: 0.6222
# Company: AGFS, Model: BaseLSTM, Epoch [120/120], Loss: 0.6194
# Company: AGFS, Model: BaseLSTM, TP: 15, TN: 10, FP: 26, FN: 8
# Company: AMGN, Model: BaseRNN, Epoch [10/120], Loss: 0.6898
# Company: AMGN, Model: BaseRNN, Epoch [20/120], Loss: 0.6872
# Company: AMGN, Model: BaseRNN, Epoch [30/120], Loss: 0.6810
# Company: AMGN, Model: BaseRNN, Epoch [40/120], Loss: 0.6785
# Company: AMGN, Model: BaseRNN, Epoch [50/120], Loss: 0.6769
# Company: AMGN, Model: BaseRNN, Epoch [60/120], Loss: 0.6753
# Company: AMGN, Model: BaseRNN, Epoch [70/120], Loss: 0.6735
# Company: AMGN, Model: BaseRNN, Epoch [80/120], Loss: 0.6715
# Company: AMGN, Model: BaseRNN, Epoch [90/120], Loss: 0.6693
# Company: AMGN, Model: BaseRNN, Epoch [100/120], Loss: 0.6669
# Company: AMGN, Model: BaseRNN, Epoch [110/120], Loss: 0.6642
# Company: AMGN, Model: BaseRNN, Epoch [120/120], Loss: 0.6614
# Company: AMGN, Model: BaseRNN, TP: 17, TN: 10, FP: 16, FN: 16
# Company: AMGN, Model: BaseLSTM, Epoch [10/120], Loss: 0.6902
# Company: AMGN, Model: BaseLSTM, Epoch [20/120], Loss: 0.6901
# Company: AMGN, Model: BaseLSTM, Epoch [30/120], Loss: 0.6900
# Company: AMGN, Model: BaseLSTM, Epoch [40/120], Loss: 0.6899
# Company: AMGN, Model: BaseLSTM, Epoch [50/120], Loss: 0.6899
# Company: AMGN, Model: BaseLSTM, Epoch [60/120], Loss: 0.6898
# Company: AMGN, Model: BaseLSTM, Epoch [70/120], Loss: 0.6898
# Company: AMGN, Model: BaseLSTM, Epoch [80/120], Loss: 0.6897
# Company: AMGN, Model: BaseLSTM, Epoch [90/120], Loss: 0.6895
# Company: AMGN, Model: BaseLSTM, Epoch [100/120], Loss: 0.6891
# Company: AMGN, Model: BaseLSTM, Epoch [110/120], Loss: 0.6874
# Company: AMGN, Model: BaseLSTM, Epoch [120/120], Loss: 0.6826
# Company: AMGN, Model: BaseLSTM, TP: 26, TN: 4, FP: 22, FN: 7
# Company: AMZN, Model: BaseRNN, Epoch [10/120], Loss: 0.6901
# Company: AMZN, Model: BaseRNN, Epoch [20/120], Loss: 0.6878
# Company: AMZN, Model: BaseRNN, Epoch [30/120], Loss: 0.6857
# Company: AMZN, Model: BaseRNN, Epoch [40/120], Loss: 0.6839
# Company: AMZN, Model: BaseRNN, Epoch [50/120], Loss: 0.6826
# Company: BAC, Model: BaseRNN, Epoch [110/120], Loss: 0.6682
# Company: BAC, Model: BaseRNN, Epoch [120/120], Loss: 0.6661
# Company: BAC, Model: BaseRNN, TP: 15, TN: 28, FP: 6, FN: 10
# Company: BAC, Model: BaseLSTM, Epoch [10/120], Loss: 0.6901
# Company: BAC, Model: BaseLSTM, Epoch [20/120], Loss: 0.6895
# Company: BAC, Model: BaseLSTM, Epoch [30/120], Loss: 0.6891
# Company: BAC, Model: BaseLSTM, Epoch [40/120], Loss: 0.6884
# Company: BAC, Model: BaseLSTM, Epoch [50/120], Loss: 0.6875
# Company: BAC, Model: BaseLSTM, Epoch [60/120], Loss: 0.6861
# Company: BAC, Model: BaseLSTM, Epoch [70/120], Loss: 0.6843
# Company: BAC, Model: BaseLSTM, Epoch [80/120], Loss: 0.6826
# Company: BAC, Model: BaseLSTM, Epoch [90/120], Loss: 0.6810
# Company: BAC, Model: BaseLSTM, Epoch [100/120], Loss: 0.6791
# Company: BAC, Model: BaseLSTM, Epoch [110/120], Loss: 0.6769
# Company: BAC, Model: BaseLSTM, Epoch [120/120], Loss: 0.6744
# Company: BAC, Model: BaseLSTM, TP: 8, TN: 32, FP: 2, FN: 17
# Company: BBL, Model: BaseRNN, Epoch [10/120], Loss: 0.6929
# Company: BBL, Model: BaseRNN, Epoch [20/120], Loss: 0.6910
# Company: BBL, Model: BaseRNN, Epoch [30/120], Loss: 0.6888
# Company: BBL, Model: BaseRNN, Epoch [40/120], Loss: 0.6840
# Company: BBL, Model: BaseRNN, Epoch [50/120], Loss: 0.6783
# Company: BBL, Model: BaseRNN, Epoch [60/120], Loss: 0.6687
# Company: BBL, Model: BaseRNN, Epoch [70/120], Loss: 0.6633
# Company: BBL, Model: BaseRNN, Epoch [80/120], Loss: 0.6609
# Company: BBL, Model: BaseRNN, Epoch [90/120], Loss: 0.6593
# Company: BBL, Model: BaseRNN, Epoch [100/120], Loss: 0.6580
# Company: BBL, Model: BaseRNN, Epoch [110/120], Loss: 0.6569
# Company: BBL, Model: BaseRNN, Epoch [120/120], Loss: 0.6559
# Company: BBL, Model: BaseRNN, TP: 17, TN: 3, FP: 35, FN: 4
# Company: BBL, Model: BaseLSTM, Epoch [10/120], Loss: 0.6915
# Company: BBL, Model: BaseLSTM, Epoch [20/120], Loss: 0.6902
# Company: BBL, Model: BaseLSTM, Epoch [30/120], Loss: 0.6878
# Company: BBL, Model: BaseLSTM, Epoch [40/120], Loss: 0.6792
# Company: BBL, Model: BaseLSTM, Epoch [50/120], Loss: 0.6760
# Company: BBL, Model: BaseLSTM, Epoch [60/120], Loss: 0.6746
# Company: BBL, Model: BaseLSTM, Epoch [70/120], Loss: 0.6738
# Company: BBL, Model: BaseLSTM, Epoch [80/120], Loss: 0.6732
# Company: BBL, Model: BaseLSTM, Epoch [90/120], Loss: 0.6726
# Company: BBL, Model: BaseLSTM, Epoch [100/120], Loss: 0.6719
# Company: BBL, Model: BaseLSTM, Epoch [110/120], Loss: 0.6710
# Company: BBL, Model: BaseLSTM, Epoch [120/120], Loss: 0.6700
# Company: BHP, Model: BaseLSTM, Epoch [20/120], Loss: 0.6906
# Company: BHP, Model: BaseLSTM, Epoch [30/120], Loss: 0.6867
# Company: BHP, Model: BaseLSTM, Epoch [40/120], Loss: 0.6813
# Company: BHP, Model: BaseLSTM, Epoch [50/120], Loss: 0.6786
# Company: BHP, Model: BaseLSTM, Epoch [60/120], Loss: 0.6763
# Company: BHP, Model: BaseLSTM, Epoch [70/120], Loss: 0.6744
# Company: BHP, Model: BaseLSTM, Epoch [80/120], Loss: 0.6773
# Company: BHP, Model: BaseLSTM, Epoch [90/120], Loss: 0.6715
# Company: BHP, Model: BaseLSTM, Epoch [100/120], Loss: 0.6699
# Company: BHP, Model: BaseLSTM, Epoch [110/120], Loss: 0.6684
# Company: BHP, Model: BaseLSTM, Epoch [120/120], Loss: 0.6675
# Company: BHP, Model: BaseLSTM, TP: 20, TN: 11, FP: 24, FN: 4
# Company: BP, Model: BaseRNN, Epoch [10/120], Loss: 0.6914
# Company: BP, Model: BaseRNN, Epoch [20/120], Loss: 0.6910
# Company: BP, Model: BaseRNN, Epoch [30/120], Loss: 0.6903
# Company: BP, Model: BaseRNN, Epoch [40/120], Loss: 0.6892
# Company: BP, Model: BaseRNN, Epoch [50/120], Loss: 0.6873
# Company: BP, Model: BaseRNN, Epoch [60/120], Loss: 0.6856
# Company: BP, Model: BaseRNN, Epoch [70/120], Loss: 0.6843
# Company: BP, Model: BaseRNN, Epoch [80/120], Loss: 0.6832
# Company: BP, Model: BaseRNN, Epoch [90/120], Loss: 0.6821
# Company: BP, Model: BaseRNN, Epoch [100/120], Loss: 0.6810
# Company: BP, Model: BaseRNN, Epoch [110/120], Loss: 0.6796
# Company: BP, Model: BaseRNN, Epoch [120/120], Loss: 0.6781
# Company: BP, Model: BaseRNN, TP: 5, TN: 29, FP: 8, FN: 17
# Company: BP, Model: BaseLSTM, Epoch [10/120], Loss: 0.6915
# Company: BP, Model: BaseLSTM, Epoch [20/120], Loss: 0.6914
# Company: BP, Model: BaseLSTM, Epoch [30/120], Loss: 0.6912
# Company: BP, Model: BaseLSTM, Epoch [40/120], Loss: 0.6911
# Company: BP, Model: BaseLSTM, Epoch [50/120], Loss: 0.6909
# Company: BP, Model: BaseLSTM, Epoch [60/120], Loss: 0.6906
# Company: BP, Model: BaseLSTM, Epoch [70/120], Loss: 0.6901
# Company: BP, Model: BaseLSTM, Epoch [80/120], Loss: 0.6895
# Company: BP, Model: BaseLSTM, Epoch [90/120], Loss: 0.6890
# Company: BP, Model: BaseLSTM, Epoch [100/120], Loss: 0.6883
# Company: BP, Model: BaseLSTM, Epoch [110/120], Loss: 0.6870
# Company: BP, Model: BaseLSTM, Epoch [120/120], Loss: 0.6843
# Company: BP, Model: BaseLSTM, TP: 5, TN: 29, FP: 8, FN: 17
# Company: BRK-A, Model: BaseRNN, Epoch [10/120], Loss: 0.6897
# Company: BRK-A, Model: BaseRNN, Epoch [20/120], Loss: 0.6882
# Company: BRK-A, Model: BaseRNN, Epoch [30/120], Loss: 0.6866
# Company: C, Model: BaseRNN, Epoch [70/120], Loss: 0.6724
# Company: C, Model: BaseRNN, Epoch [80/120], Loss: 0.6714
# Company: C, Model: BaseRNN, Epoch [90/120], Loss: 0.6706
# Company: C, Model: BaseRNN, Epoch [100/120], Loss: 0.6700
# Company: C, Model: BaseRNN, Epoch [110/120], Loss: 0.6695
# Company: C, Model: BaseRNN, Epoch [120/120], Loss: 0.6690
# Company: C, Model: BaseRNN, TP: 15, TN: 22, FP: 13, FN: 9
# Company: C, Model: BaseLSTM, Epoch [10/120], Loss: 0.6929
# Company: C, Model: BaseLSTM, Epoch [20/120], Loss: 0.6923
# Company: C, Model: BaseLSTM, Epoch [30/120], Loss: 0.6921
# Company: C, Model: BaseLSTM, Epoch [40/120], Loss: 0.6919
# Company: C, Model: BaseLSTM, Epoch [50/120], Loss: 0.6918
# Company: C, Model: BaseLSTM, Epoch [60/120], Loss: 0.6915
# Company: C, Model: BaseLSTM, Epoch [70/120], Loss: 0.6910
# Company: C, Model: BaseLSTM, Epoch [80/120], Loss: 0.6897
# Company: C, Model: BaseLSTM, Epoch [90/120], Loss: 0.6863
# Company: C, Model: BaseLSTM, Epoch [100/120], Loss: 0.6813
# Company: C, Model: BaseLSTM, Epoch [110/120], Loss: 0.6758
# Company: C, Model: BaseLSTM, Epoch [120/120], Loss: 0.6723
# Company: C, Model: BaseLSTM, TP: 13, TN: 15, FP: 20, FN: 11
# Company: CAT, Model: BaseRNN, Epoch [10/120], Loss: 0.6926
# Company: CAT, Model: BaseRNN, Epoch [20/120], Loss: 0.6917
# Company: CAT, Model: BaseRNN, Epoch [30/120], Loss: 0.6897
# Company: CAT, Model: BaseRNN, Epoch [40/120], Loss: 0.6860
# Company: CAT, Model: BaseRNN, Epoch [50/120], Loss: 0.6841
# Company: CAT, Model: BaseRNN, Epoch [60/120], Loss: 0.6833
# Company: CAT, Model: BaseRNN, Epoch [70/120], Loss: 0.6828
# Company: CAT, Model: BaseRNN, Epoch [80/120], Loss: 0.6823
# Company: CAT, Model: BaseRNN, Epoch [90/120], Loss: 0.6818
# Company: CAT, Model: BaseRNN, Epoch [100/120], Loss: 0.6812
# Company: CAT, Model: BaseRNN, Epoch [110/120], Loss: 0.6806
# Company: CAT, Model: BaseRNN, Epoch [120/120], Loss: 0.6800
# Company: CAT, Model: BaseRNN, TP: 8, TN: 20, FP: 11, FN: 20
# Company: CAT, Model: BaseLSTM, Epoch [10/120], Loss: 0.6927
# Company: CAT, Model: BaseLSTM, Epoch [20/120], Loss: 0.6926
# Company: CAT, Model: BaseLSTM, Epoch [30/120], Loss: 0.6925
# Company: CAT, Model: BaseLSTM, Epoch [40/120], Loss: 0.6924
# Company: CAT, Model: BaseLSTM, Epoch [50/120], Loss: 0.6921
# Company: CAT, Model: BaseLSTM, Epoch [60/120], Loss: 0.6909
# Company: CAT, Model: BaseLSTM, Epoch [70/120], Loss: 0.6850
# Company: CAT, Model: BaseLSTM, Epoch [80/120], Loss: 0.6807
# Company: CAT, Model: BaseLSTM, Epoch [90/120], Loss: 0.6791
# Company: CAT, Model: BaseLSTM, Epoch [100/120], Loss: 0.6781
# Company: CAT, Model: BaseLSTM, Epoch [110/120], Loss: 0.6773
# Company: CAT, Model: BaseLSTM, Epoch [120/120], Loss: 0.6767
# Company: CAT, Model: BaseLSTM, TP: 3, TN: 27, FP: 4, FN: 25
# Company: CELG, Model: BaseRNN, Epoch [10/120], Loss: 0.6920
# Company: CELG, Model: BaseRNN, Epoch [20/120], Loss: 0.6918
# Company: CELG, Model: BaseRNN, Epoch [30/120], Loss: 0.6916
# Company: CELG, Model: BaseRNN, Epoch [40/120], Loss: 0.6914
# Company: CELG, Model: BaseRNN, Epoch [50/120], Loss: 0.6912
# Company: CELG, Model: BaseRNN, Epoch [60/120], Loss: 0.6910
# Company: CELG, Model: BaseRNN, Epoch [70/120], Loss: 0.6908
# Company: CELG, Model: BaseRNN, Epoch [80/120], Loss: 0.6903
# Company: CELG, Model: BaseRNN, Epoch [90/120], Loss: 0.6895
# Company: CELG, Model: BaseRNN, Epoch [100/120], Loss: 0.6877
# Company: CELG, Model: BaseRNN, Epoch [110/120], Loss: 0.6860
# Company: CELG, Model: BaseRNN, Epoch [120/120], Loss: 0.6846
# Company: CELG, Model: BaseRNN, TP: 26, TN: 9, FP: 20, FN: 4
# Company: CELG, Model: BaseLSTM, Epoch [10/120], Loss: 0.6917
# Company: CELG, Model: BaseLSTM, Epoch [20/120], Loss: 0.6911
# Company: CELG, Model: BaseLSTM, Epoch [30/120], Loss: 0.6901
# Company: CELG, Model: BaseLSTM, Epoch [40/120], Loss: 0.6876
# Company: CELG, Model: BaseLSTM, Epoch [50/120], Loss: 0.6850
# Company: CELG, Model: BaseLSTM, Epoch [60/120], Loss: 0.6840
# Company: CELG, Model: BaseLSTM, Epoch [70/120], Loss: 0.6832
# Company: CELG, Model: BaseLSTM, Epoch [80/120], Loss: 0.6825
# Company: CELG, Model: BaseLSTM, Epoch [90/120], Loss: 0.6816
# Company: CELG, Model: BaseLSTM, Epoch [100/120], Loss: 0.6809
# Company: CELG, Model: BaseLSTM, Epoch [110/120], Loss: 0.6802
# Company: CELG, Model: BaseLSTM, Epoch [120/120], Loss: 0.6797
# Company: CELG, Model: BaseLSTM, TP: 23, TN: 8, FP: 21, FN: 7
# Company: CHL, Model: BaseRNN, Epoch [10/120], Loss: 0.6875
# Company: CHL, Model: BaseRNN, Epoch [20/120], Loss: 0.6866
# Company: CHL, Model: BaseRNN, Epoch [30/120], Loss: 0.6855
# Company: CHL, Model: BaseRNN, Epoch [40/120], Loss: 0.6833
# Company: CHL, Model: BaseRNN, Epoch [50/120], Loss: 0.6807
# Company: CHL, Model: BaseRNN, Epoch [60/120], Loss: 0.6788
# Company: CHL, Model: BaseRNN, Epoch [70/120], Loss: 0.6775
# Company: CHL, Model: BaseRNN, Epoch [80/120], Loss: 0.6765
# Company: CHL, Model: BaseRNN, Epoch [90/120], Loss: 0.6758
# Company: CHL, Model: BaseRNN, Epoch [100/120], Loss: 0.6750
# Company: CHL, Model: BaseRNN, Epoch [110/120], Loss: 0.6744
# Company: CHL, Model: BaseRNN, Epoch [120/120], Loss: 0.6737
# Company: CHL, Model: BaseRNN, TP: 25, TN: 7, FP: 24, FN: 3
# Company: CHL, Model: BaseLSTM, Epoch [10/120], Loss: 0.6877
# Company: CHL, Model: BaseLSTM, Epoch [20/120], Loss: 0.6862
# Company: CHL, Model: BaseLSTM, Epoch [30/120], Loss: 0.6856
# Company: CHL, Model: BaseLSTM, Epoch [40/120], Loss: 0.6851
# Company: CHL, Model: BaseLSTM, Epoch [50/120], Loss: 0.6844
# Company: CHL, Model: BaseLSTM, Epoch [60/120], Loss: 0.6835
# Company: CHL, Model: BaseLSTM, Epoch [70/120], Loss: 0.6824
# Company: CHL, Model: BaseLSTM, Epoch [80/120], Loss: 0.6811
# Company: CHL, Model: BaseLSTM, Epoch [90/120], Loss: 0.6800
# Company: CHL, Model: BaseLSTM, Epoch [100/120], Loss: 0.6804
# Company: CHL, Model: BaseLSTM, Epoch [110/120], Loss: 0.6781
# Company: CHL, Model: BaseLSTM, Epoch [120/120], Loss: 0.6838
# Company: CHL, Model: BaseLSTM, TP: 27, TN: 0, FP: 31, FN: 1
# Company: CHTR, Model: BaseRNN, Epoch [10/120], Loss: 0.6899
# Company: CHTR, Model: BaseRNN, Epoch [20/120], Loss: 0.6896
# Company: CHTR, Model: BaseRNN, Epoch [30/120], Loss: 0.6894
# Company: CHTR, Model: BaseRNN, Epoch [40/120], Loss: 0.6892
# Company: CHTR, Model: BaseRNN, Epoch [50/120], Loss: 0.6889
# Company: CHTR, Model: BaseRNN, Epoch [60/120], Loss: 0.6884
# Company: CHTR, Model: BaseRNN, Epoch [70/120], Loss: 0.6866
# Company: CHTR, Model: BaseRNN, Epoch [80/120], Loss: 0.6837
# Company: CHTR, Model: BaseRNN, Epoch [90/120], Loss: 0.6814
# Company: CHTR, Model: BaseRNN, Epoch [100/120], Loss: 0.6795
# Company: CHTR, Model: BaseRNN, Epoch [110/120], Loss: 0.6783
# Company: CHTR, Model: BaseRNN, Epoch [120/120], Loss: 0.6775
# Company: CHTR, Model: BaseRNN, TP: 0, TN: 29, FP: 0, FN: 30
# Company: CHTR, Model: BaseLSTM, Epoch [10/120], Loss: 0.6904
# Company: CHTR, Model: BaseLSTM, Epoch [20/120], Loss: 0.6874
# Company: CHTR, Model: BaseLSTM, Epoch [30/120], Loss: 0.6867
# Company: CHTR, Model: BaseLSTM, Epoch [40/120], Loss: 0.6862
# Company: CHTR, Model: BaseLSTM, Epoch [50/120], Loss: 0.6860
# Company: CHTR, Model: BaseLSTM, Epoch [60/120], Loss: 0.6858
# Company: CHTR, Model: BaseLSTM, Epoch [70/120], Loss: 0.6856
# Company: CHTR, Model: BaseLSTM, Epoch [80/120], Loss: 0.6855
# Company: CHTR, Model: BaseLSTM, Epoch [90/120], Loss: 0.6853
# Company: CHTR, Model: BaseLSTM, Epoch [100/120], Loss: 0.6852
# Company: CHTR, Model: BaseLSTM, Epoch [110/120], Loss: 0.6869
# Company: CHTR, Model: BaseLSTM, Epoch [120/120], Loss: 0.6850
# Company: CHTR, Model: BaseLSTM, TP: 0, TN: 29, FP: 0, FN: 30
# Company: CMCSA, Model: BaseRNN, Epoch [10/120], Loss: 0.6916
# Company: CMCSA, Model: BaseRNN, Epoch [20/120], Loss: 0.6911
# Company: CMCSA, Model: BaseRNN, Epoch [30/120], Loss: 0.6906
# Company: CMCSA, Model: BaseRNN, Epoch [40/120], Loss: 0.6899
# Company: CMCSA, Model: BaseRNN, Epoch [50/120], Loss: 0.6891
# Company: CMCSA, Model: BaseRNN, Epoch [60/120], Loss: 0.6882
# Company: CMCSA, Model: BaseRNN, Epoch [70/120], Loss: 0.6872
# Company: CMCSA, Model: BaseRNN, Epoch [80/120], Loss: 0.6863
# Company: CMCSA, Model: BaseRNN, Epoch [90/120], Loss: 0.6855
# Company: CMCSA, Model: BaseRNN, Epoch [100/120], Loss: 0.6848
# Company: CMCSA, Model: BaseRNN, Epoch [110/120], Loss: 0.6842
# Company: CMCSA, Model: BaseRNN, Epoch [120/120], Loss: 0.6837
# Company: CMCSA, Model: BaseRNN, TP: 15, TN: 13, FP: 19, FN: 12
# Company: CMCSA, Model: BaseLSTM, Epoch [10/120], Loss: 0.6915
# Company: CMCSA, Model: BaseLSTM, Epoch [20/120], Loss: 0.6913
# Company: CMCSA, Model: BaseLSTM, Epoch [30/120], Loss: 0.6912
# Company: CMCSA, Model: BaseLSTM, Epoch [40/120], Loss: 0.6909
# Company: CMCSA, Model: BaseLSTM, Epoch [50/120], Loss: 0.6904
# Company: CMCSA, Model: BaseLSTM, Epoch [60/120], Loss: 0.6895
# Company: CMCSA, Model: BaseLSTM, Epoch [70/120], Loss: 0.6884
# Company: CMCSA, Model: BaseLSTM, Epoch [80/120], Loss: 0.6870
# Company: CMCSA, Model: BaseLSTM, Epoch [90/120], Loss: 0.6844
# Company: CMCSA, Model: BaseLSTM, Epoch [100/120], Loss: 0.6775
# Company: CMCSA, Model: BaseLSTM, Epoch [110/120], Loss: 0.6730
# Company: CMCSA, Model: BaseLSTM, Epoch [120/120], Loss: 0.6693
# Company: CMCSA, Model: BaseLSTM, TP: 15, TN: 15, FP: 17, FN: 12
# Company: CODI, Model: BaseRNN, Epoch [10/120], Loss: 0.6854
# Company: CODI, Model: BaseRNN, Epoch [20/120], Loss: 0.6797
# Company: CODI, Model: BaseRNN, Epoch [30/120], Loss: 0.6748
# Company: CODI, Model: BaseRNN, Epoch [40/120], Loss: 0.6704
# Company: CODI, Model: BaseRNN, Epoch [50/120], Loss: 0.6667
# Company: CODI, Model: BaseRNN, Epoch [60/120], Loss: 0.6635
# Company: CODI, Model: BaseRNN, Epoch [70/120], Loss: 0.6606
# Company: CODI, Model: BaseRNN, Epoch [80/120], Loss: 0.6581
# Company: CODI, Model: BaseRNN, Epoch [90/120], Loss: 0.6559
# Company: CODI, Model: BaseRNN, Epoch [100/120], Loss: 0.6540
# Company: CODI, Model: BaseRNN, Epoch [110/120], Loss: 0.6521
# Company: CODI, Model: BaseRNN, Epoch [120/120], Loss: 0.6502
# Company: CODI, Model: BaseRNN, TP: 3, TN: 29, FP: 5, FN: 22
# Company: CODI, Model: BaseLSTM, Epoch [10/120], Loss: 0.6888
# Company: CODI, Model: BaseLSTM, Epoch [20/120], Loss: 0.6820
# Company: CODI, Model: BaseLSTM, Epoch [30/120], Loss: 0.6805
# Company: CODI, Model: BaseLSTM, Epoch [40/120], Loss: 0.6792
# Company: CODI, Model: BaseLSTM, Epoch [50/120], Loss: 0.6778
# Company: CODI, Model: BaseLSTM, Epoch [60/120], Loss: 0.6763
# Company: CODI, Model: BaseLSTM, Epoch [70/120], Loss: 0.6747
# Company: CODI, Model: BaseLSTM, Epoch [80/120], Loss: 0.6732
# Company: CODI, Model: BaseLSTM, Epoch [90/120], Loss: 0.6719
# Company: CODI, Model: BaseLSTM, Epoch [100/120], Loss: 0.6707
# Company: CODI, Model: BaseLSTM, Epoch [110/120], Loss: 0.6697
# Company: CODI, Model: BaseLSTM, Epoch [120/120], Loss: 0.6687
# Company: CODI, Model: BaseLSTM, TP: 3, TN: 32, FP: 2, FN: 22
# Company: CSCO, Model: BaseRNN, Epoch [10/120], Loss: 0.6907
# Company: CSCO, Model: BaseRNN, Epoch [20/120], Loss: 0.6905
# Company: CSCO, Model: BaseRNN, Epoch [30/120], Loss: 0.6903
# Company: CSCO, Model: BaseRNN, Epoch [40/120], Loss: 0.6900
# Company: CSCO, Model: BaseRNN, Epoch [50/120], Loss: 0.6895
# Company: CSCO, Model: BaseRNN, Epoch [60/120], Loss: 0.6880
# Company: CSCO, Model: BaseRNN, Epoch [70/120], Loss: 0.6855
# Company: CSCO, Model: BaseRNN, Epoch [80/120], Loss: 0.6838
# Company: CSCO, Model: BaseRNN, Epoch [90/120], Loss: 0.6819
# Company: CSCO, Model: BaseRNN, Epoch [100/120], Loss: 0.6796
# Company: CSCO, Model: BaseRNN, Epoch [110/120], Loss: 0.6773
# Company: CSCO, Model: BaseRNN, Epoch [120/120], Loss: 0.6752
# Company: CSCO, Model: BaseRNN, TP: 17, TN: 15, FP: 16, FN: 11
# Company: CSCO, Model: BaseLSTM, Epoch [10/120], Loss: 0.6897
# Company: CSCO, Model: BaseLSTM, Epoch [20/120], Loss: 0.6876
# Company: CSCO, Model: BaseLSTM, Epoch [30/120], Loss: 0.6853
# Company: CSCO, Model: BaseLSTM, Epoch [40/120], Loss: 0.6838
# Company: CSCO, Model: BaseLSTM, Epoch [50/120], Loss: 0.6835
# Company: CSCO, Model: BaseLSTM, Epoch [60/120], Loss: 0.6833
# Company: CSCO, Model: BaseLSTM, Epoch [70/120], Loss: 0.6832
# Company: CSCO, Model: BaseLSTM, Epoch [80/120], Loss: 0.6831
# Company: CSCO, Model: BaseLSTM, Epoch [90/120], Loss: 0.6830
# Company: CSCO, Model: BaseLSTM, Epoch [100/120], Loss: 0.6829
# Company: CSCO, Model: BaseLSTM, Epoch [110/120], Loss: 0.6828
# Company: CSCO, Model: BaseLSTM, Epoch [120/120], Loss: 0.6828
# Company: CSCO, Model: BaseLSTM, TP: 18, TN: 17, FP: 14, FN: 10
# Company: CVX, Model: BaseRNN, Epoch [10/120], Loss: 0.6921
# Company: CVX, Model: BaseRNN, Epoch [20/120], Loss: 0.6917
# Company: CVX, Model: BaseRNN, Epoch [30/120], Loss: 0.6911
# Company: CVX, Model: BaseRNN, Epoch [40/120], Loss: 0.6900
# Company: CVX, Model: BaseRNN, Epoch [50/120], Loss: 0.6880
# Company: CVX, Model: BaseRNN, Epoch [60/120], Loss: 0.6859
# Company: CVX, Model: BaseRNN, Epoch [70/120], Loss: 0.6846
# Company: CVX, Model: BaseRNN, Epoch [80/120], Loss: 0.6838
# Company: CVX, Model: BaseRNN, Epoch [90/120], Loss: 0.6832
# Company: CVX, Model: BaseRNN, Epoch [100/120], Loss: 0.6826
# Company: CVX, Model: BaseRNN, Epoch [110/120], Loss: 0.6821
# Company: CVX, Model: BaseRNN, Epoch [120/120], Loss: 0.6815
# Company: CVX, Model: BaseRNN, TP: 8, TN: 24, FP: 9, FN: 18
# Company: CVX, Model: BaseLSTM, Epoch [10/120], Loss: 0.6917
# Company: CVX, Model: BaseLSTM, Epoch [20/120], Loss: 0.6915
# Company: CVX, Model: BaseLSTM, Epoch [30/120], Loss: 0.6913
# Company: CVX, Model: BaseLSTM, Epoch [40/120], Loss: 0.6909
# Company: CVX, Model: BaseLSTM, Epoch [50/120], Loss: 0.6893
# Company: CVX, Model: BaseLSTM, Epoch [60/120], Loss: 0.6877
# Company: CVX, Model: BaseLSTM, Epoch [70/120], Loss: 0.6865
# Company: CVX, Model: BaseLSTM, Epoch [80/120], Loss: 0.6852
# Company: CVX, Model: BaseLSTM, Epoch [90/120], Loss: 0.6839
# Company: CVX, Model: BaseLSTM, Epoch [100/120], Loss: 0.6829
# Company: CVX, Model: BaseLSTM, Epoch [110/120], Loss: 0.6858
# Company: CVX, Model: BaseLSTM, Epoch [120/120], Loss: 0.6814
# Company: CVX, Model: BaseLSTM, TP: 0, TN: 33, FP: 0, FN: 26
# Company: D, Model: BaseRNN, Epoch [10/120], Loss: 0.6882
# Company: D, Model: BaseRNN, Epoch [20/120], Loss: 0.6866
# Company: D, Model: BaseRNN, Epoch [30/120], Loss: 0.6852
# Company: D, Model: BaseRNN, Epoch [40/120], Loss: 0.6833
# Company: D, Model: BaseRNN, Epoch [50/120], Loss: 0.6808
# Company: D, Model: BaseRNN, Epoch [60/120], Loss: 0.6778
# Company: D, Model: BaseRNN, Epoch [70/120], Loss: 0.6751
# Company: D, Model: BaseRNN, Epoch [80/120], Loss: 0.6717
# Company: D, Model: BaseRNN, Epoch [90/120], Loss: 0.6682
# Company: D, Model: BaseRNN, Epoch [100/120], Loss: 0.6654
# Company: D, Model: BaseRNN, Epoch [110/120], Loss: 0.6628
# Company: D, Model: BaseRNN, Epoch [120/120], Loss: 0.6605
# Company: D, Model: BaseRNN, TP: 28, TN: 4, FP: 25, FN: 2
# Company: D, Model: BaseLSTM, Epoch [10/120], Loss: 0.6891
# Company: D, Model: BaseLSTM, Epoch [20/120], Loss: 0.6874
# Company: D, Model: BaseLSTM, Epoch [30/120], Loss: 0.6861
# Company: D, Model: BaseLSTM, Epoch [40/120], Loss: 0.6849
# Company: D, Model: BaseLSTM, Epoch [50/120], Loss: 0.6834
# Company: D, Model: BaseLSTM, Epoch [60/120], Loss: 0.6816
# Company: D, Model: BaseLSTM, Epoch [70/120], Loss: 0.6798
# Company: D, Model: BaseLSTM, Epoch [80/120], Loss: 0.6781
# Company: D, Model: BaseLSTM, Epoch [90/120], Loss: 0.6766
# Company: D, Model: BaseLSTM, Epoch [100/120], Loss: 0.6751
# Company: D, Model: BaseLSTM, Epoch [110/120], Loss: 0.6736
# Company: D, Model: BaseLSTM, Epoch [120/120], Loss: 0.6723
# Company: D, Model: BaseLSTM, TP: 26, TN: 4, FP: 25, FN: 4
# Company: DHR, Model: BaseRNN, Epoch [10/120], Loss: 0.6867
# Company: DHR, Model: BaseRNN, Epoch [20/120], Loss: 0.6807
# Company: DHR, Model: BaseRNN, Epoch [30/120], Loss: 0.6764
# Company: DHR, Model: BaseRNN, Epoch [40/120], Loss: 0.6740
# Company: DHR, Model: BaseRNN, Epoch [50/120], Loss: 0.6722
# Company: DHR, Model: BaseRNN, Epoch [60/120], Loss: 0.6706
# Company: DHR, Model: BaseRNN, Epoch [70/120], Loss: 0.6691
# Company: DHR, Model: BaseRNN, Epoch [80/120], Loss: 0.6676
# Company: DHR, Model: BaseRNN, Epoch [90/120], Loss: 0.6660
# Company: DHR, Model: BaseRNN, Epoch [100/120], Loss: 0.6644
# Company: DHR, Model: BaseRNN, Epoch [110/120], Loss: 0.6627
# Company: DHR, Model: BaseRNN, Epoch [120/120], Loss: 0.6613
# Company: DHR, Model: BaseRNN, TP: 0, TN: 29, FP: 0, FN: 30
# Company: DHR, Model: BaseLSTM, Epoch [10/120], Loss: 0.6894
# Company: DHR, Model: BaseLSTM, Epoch [20/120], Loss: 0.6885
# Company: DHR, Model: BaseLSTM, Epoch [30/120], Loss: 0.6876
# Company: DHR, Model: BaseLSTM, Epoch [40/120], Loss: 0.6860
# Company: DHR, Model: BaseLSTM, Epoch [50/120], Loss: 0.6831
# Company: DHR, Model: BaseLSTM, Epoch [60/120], Loss: 0.6799
# Company: DHR, Model: BaseLSTM, Epoch [70/120], Loss: 0.6777
# Company: DHR, Model: BaseLSTM, Epoch [80/120], Loss: 0.6763
# Company: DHR, Model: BaseLSTM, Epoch [90/120], Loss: 0.6754
# Company: DHR, Model: BaseLSTM, Epoch [100/120], Loss: 0.6748
# Company: DHR, Model: BaseLSTM, Epoch [110/120], Loss: 0.6743
# Company: DHR, Model: BaseLSTM, Epoch [120/120], Loss: 0.6738
# Company: DHR, Model: BaseLSTM, TP: 0, TN: 29, FP: 0, FN: 30
# Company: DIS, Model: BaseRNN, Epoch [10/120], Loss: 0.6863
# Company: DIS, Model: BaseRNN, Epoch [20/120], Loss: 0.6858
# Company: DIS, Model: BaseRNN, Epoch [30/120], Loss: 0.6853
# Company: DIS, Model: BaseRNN, Epoch [40/120], Loss: 0.6847
# Company: DIS, Model: BaseRNN, Epoch [50/120], Loss: 0.6836
# Company: DIS, Model: BaseRNN, Epoch [60/120], Loss: 0.6824
# Company: DIS, Model: BaseRNN, Epoch [70/120], Loss: 0.6812
# Company: DIS, Model: BaseRNN, Epoch [80/120], Loss: 0.6798
# Company: DIS, Model: BaseRNN, Epoch [90/120], Loss: 0.6785
# Company: DIS, Model: BaseRNN, Epoch [100/120], Loss: 0.6772
# Company: DIS, Model: BaseRNN, Epoch [110/120], Loss: 0.6760
# Company: DIS, Model: BaseRNN, Epoch [120/120], Loss: 0.6747
# Company: DIS, Model: BaseRNN, TP: 28, TN: 7, FP: 19, FN: 5
# Company: DIS, Model: BaseLSTM, Epoch [10/120], Loss: 0.6868
# Company: DIS, Model: BaseLSTM, Epoch [20/120], Loss: 0.6861
# Company: DIS, Model: BaseLSTM, Epoch [30/120], Loss: 0.6854
# Company: DIS, Model: BaseLSTM, Epoch [40/120], Loss: 0.6843
# Company: DIS, Model: BaseLSTM, Epoch [50/120], Loss: 0.6833
# Company: DIS, Model: BaseLSTM, Epoch [60/120], Loss: 0.6814
# Company: DIS, Model: BaseLSTM, Epoch [70/120], Loss: 0.6788
# Company: DIS, Model: BaseLSTM, Epoch [80/120], Loss: 0.6764
# Company: DIS, Model: BaseLSTM, Epoch [90/120], Loss: 0.6724
# Company: DIS, Model: BaseLSTM, Epoch [100/120], Loss: 0.6681
# Company: DIS, Model: BaseLSTM, Epoch [110/120], Loss: 0.6646
# Company: DIS, Model: BaseLSTM, Epoch [120/120], Loss: 0.6694
# Company: DIS, Model: BaseLSTM, TP: 30, TN: 3, FP: 23, FN: 3
# Company: DUK, Model: BaseRNN, Epoch [10/120], Loss: 0.6892
# Company: DUK, Model: BaseRNN, Epoch [20/120], Loss: 0.6879
# Company: DUK, Model: BaseRNN, Epoch [30/120], Loss: 0.6858
# Company: DUK, Model: BaseRNN, Epoch [40/120], Loss: 0.6842
# Company: DUK, Model: BaseRNN, Epoch [50/120], Loss: 0.6834
# Company: DUK, Model: BaseRNN, Epoch [60/120], Loss: 0.6828
# Company: DUK, Model: BaseRNN, Epoch [70/120], Loss: 0.6824
# Company: DUK, Model: BaseRNN, Epoch [80/120], Loss: 0.6820
# Company: DUK, Model: BaseRNN, Epoch [90/120], Loss: 0.6817
# Company: DUK, Model: BaseRNN, Epoch [100/120], Loss: 0.6814
# Company: DUK, Model: BaseRNN, Epoch [110/120], Loss: 0.6810
# Company: DUK, Model: BaseRNN, Epoch [120/120], Loss: 0.6807
# Company: DUK, Model: BaseRNN, TP: 24, TN: 7, FP: 17, FN: 11
# Company: DUK, Model: BaseLSTM, Epoch [10/120], Loss: 0.6898
# Company: DUK, Model: BaseLSTM, Epoch [20/120], Loss: 0.6890
# Company: DUK, Model: BaseLSTM, Epoch [30/120], Loss: 0.6885
# Company: DUK, Model: BaseLSTM, Epoch [40/120], Loss: 0.6881
# Company: DUK, Model: BaseLSTM, Epoch [50/120], Loss: 0.6876
# Company: DUK, Model: BaseLSTM, Epoch [60/120], Loss: 0.6870
# Company: DUK, Model: BaseLSTM, Epoch [70/120], Loss: 0.6862
# Company: DUK, Model: BaseLSTM, Epoch [80/120], Loss: 0.6851
# Company: DUK, Model: BaseLSTM, Epoch [90/120], Loss: 0.6837
# Company: DUK, Model: BaseLSTM, Epoch [100/120], Loss: 0.6822
# Company: DUK, Model: BaseLSTM, Epoch [110/120], Loss: 0.6802
# Company: DUK, Model: BaseLSTM, Epoch [120/120], Loss: 0.6849
# Company: DUK, Model: BaseLSTM, TP: 27, TN: 1, FP: 23, FN: 8
# Company: EXC, Model: BaseRNN, Epoch [10/120], Loss: 0.6917
# Company: EXC, Model: BaseRNN, Epoch [20/120], Loss: 0.6902
# Company: EXC, Model: BaseRNN, Epoch [30/120], Loss: 0.6877
# Company: EXC, Model: BaseRNN, Epoch [40/120], Loss: 0.6855
# Company: EXC, Model: BaseRNN, Epoch [50/120], Loss: 0.6840
# Company: EXC, Model: BaseRNN, Epoch [60/120], Loss: 0.6827
# Company: EXC, Model: BaseRNN, Epoch [70/120], Loss: 0.6815
# Company: EXC, Model: BaseRNN, Epoch [80/120], Loss: 0.6803
# Company: EXC, Model: BaseRNN, Epoch [90/120], Loss: 0.6791
# Company: EXC, Model: BaseRNN, Epoch [100/120], Loss: 0.6776
# Company: EXC, Model: BaseRNN, Epoch [110/120], Loss: 0.6755
# Company: EXC, Model: BaseRNN, Epoch [120/120], Loss: 0.6735
# Company: EXC, Model: BaseRNN, TP: 9, TN: 21, FP: 8, FN: 21
# Company: EXC, Model: BaseLSTM, Epoch [10/120], Loss: 0.6919
# Company: EXC, Model: BaseLSTM, Epoch [20/120], Loss: 0.6915
# Company: EXC, Model: BaseLSTM, Epoch [30/120], Loss: 0.6912
# Company: EXC, Model: BaseLSTM, Epoch [40/120], Loss: 0.6907
# Company: EXC, Model: BaseLSTM, Epoch [50/120], Loss: 0.6899
# Company: EXC, Model: BaseLSTM, Epoch [60/120], Loss: 0.6890
# ...
# Company: TSM, Model: BaseLSTM, Epoch [70/120], Loss: 0.6802
# Company: TSM, Model: BaseLSTM, Epoch [80/120], Loss: 0.6787
# Company: TSM, Model: BaseLSTM, Epoch [90/120], Loss: 0.6775
# Company: TSM, Model: BaseLSTM, Epoch [100/120], Loss: 0.6765
# Company: TSM, Model: BaseLSTM, Epoch [110/120], Loss: 0.6757
# Company: TSM, Model: BaseLSTM, Epoch [120/120], Loss: 0.6749
# Company: TSM, Model: BaseLSTM, TP: 4, TN: 27, FP: 2, FN: 26
# Company: UL, Model: BaseRNN, Epoch [10/120], Loss: 0.6913
# Company: UL, Model: BaseRNN, Epoch [20/120], Loss: 0.6905
# Company: UL, Model: BaseRNN, Epoch [30/120], Loss: 0.6900
# Company: UL, Model: BaseRNN, Epoch [40/120], Loss: 0.6895
# Company: UL, Model: BaseRNN, Epoch [50/120], Loss: 0.6890
# Company: UL, Model: BaseRNN, Epoch [60/120], Loss: 0.6884
# Company: UL, Model: BaseRNN, Epoch [70/120], Loss: 0.6877
# Company: UL, Model: BaseRNN, Epoch [80/120], Loss: 0.6870
# Company: UL, Model: BaseRNN, Epoch [90/120], Loss: 0.6862
# Company: UL, Model: BaseRNN, Epoch [100/120], Loss: 0.6854
# Company: UL, Model: BaseRNN, Epoch [110/120], Loss: 0.6847
# Company: UL, Model: BaseRNN, Epoch [120/120], Loss: 0.6840
# Company: UL, Model: BaseRNN, TP: 3, TN: 27, FP: 2, FN: 27
# Company: UL, Model: BaseLSTM, Epoch [10/120], Loss: 0.6912
# Company: UL, Model: BaseLSTM, Epoch [20/120], Loss: 0.6906
# Company: UL, Model: BaseLSTM, Epoch [30/120], Loss: 0.6901
# Company: UL, Model: BaseLSTM, Epoch [40/120], Loss: 0.6891
# Company: UL, Model: BaseLSTM, Epoch [50/120], Loss: 0.6869
# Company: UL, Model: BaseLSTM, Epoch [60/120], Loss: 0.6856
# Company: UL, Model: BaseLSTM, Epoch [70/120], Loss: 0.6848
# Company: UL, Model: BaseLSTM, Epoch [80/120], Loss: 0.6840
# Company: UL, Model: BaseLSTM, Epoch [90/120], Loss: 0.6832
# Company: UL, Model: BaseLSTM, Epoch [100/120], Loss: 0.6825
# Company: UL, Model: BaseLSTM, Epoch [110/120], Loss: 0.6816
# Company: UL, Model: BaseLSTM, Epoch [120/120], Loss: 0.6807
# Company: UL, Model: BaseLSTM, TP: 21, TN: 10, FP: 19, FN: 9
# Company: UN, Model: BaseRNN, Epoch [10/120], Loss: 0.6860
# Company: UN, Model: BaseRNN, Epoch [20/120], Loss: 0.6804
# Company: UN, Model: BaseRNN, Epoch [30/120], Loss: 0.6751
# Company: UN, Model: BaseRNN, Epoch [40/120], Loss: 0.6741
# Company: UN, Model: BaseRNN, Epoch [50/120], Loss: 0.6734
# Company: UN, Model: BaseRNN, Epoch [60/120], Loss: 0.6729
# Company: UN, Model: BaseRNN, Epoch [70/120], Loss: 0.6724
# Company: UN, Model: BaseRNN, Epoch [80/120], Loss: 0.6720
# Company: UN, Model: BaseRNN, Epoch [90/120], Loss: 0.6715
# Company: UN, Model: BaseRNN, Epoch [100/120], Loss: 0.6711
# Company: UN, Model: BaseRNN, Epoch [110/120], Loss: 0.6707
# Company: UN, Model: BaseRNN, Epoch [120/120], Loss: 0.6702
# Company: UN, Model: BaseRNN, TP: 10, TN: 22, FP: 6, FN: 21
# Company: UN, Model: BaseLSTM, Epoch [10/120], Loss: 0.6855
# Company: UN, Model: BaseLSTM, Epoch [20/120], Loss: 0.6841
# Company: UN, Model: BaseLSTM, Epoch [30/120], Loss: 0.6824
# Company: UN, Model: BaseLSTM, Epoch [40/120], Loss: 0.6778
# Company: UN, Model: BaseLSTM, Epoch [50/120], Loss: 0.6729
# Company: UN, Model: BaseLSTM, Epoch [60/120], Loss: 0.6681
# Company: UN, Model: BaseLSTM, Epoch [70/120], Loss: 0.6629
# Company: UN, Model: BaseLSTM, Epoch [80/120], Loss: 0.6589
# Company: UN, Model: BaseLSTM, Epoch [90/120], Loss: 0.6555
# Company: UN, Model: BaseLSTM, Epoch [100/120], Loss: 0.6523
# Company: UN, Model: BaseLSTM, Epoch [110/120], Loss: 0.6492
# Company: UN, Model: BaseLSTM, Epoch [120/120], Loss: 0.6458
# Company: UN, Model: BaseLSTM, TP: 9, TN: 25, FP: 3, FN: 22
# Company: UNH, Model: BaseRNN, Epoch [10/120], Loss: 0.6890
# Company: UNH, Model: BaseRNN, Epoch [20/120], Loss: 0.6879
# Company: UNH, Model: BaseRNN, Epoch [30/120], Loss: 0.6863
# Company: UPS, Model: BaseLSTM, Epoch [60/120], Loss: 0.6823
# Company: UPS, Model: BaseLSTM, Epoch [70/120], Loss: 0.6803
# Company: UPS, Model: BaseLSTM, Epoch [80/120], Loss: 0.6779
# Company: UPS, Model: BaseLSTM, Epoch [90/120], Loss: 0.6757
# Company: UPS, Model: BaseLSTM, Epoch [100/120], Loss: 0.6739
# Company: UPS, Model: BaseLSTM, Epoch [110/120], Loss: 0.6724
# Company: UPS, Model: BaseLSTM, Epoch [120/120], Loss: 0.6712
# Company: UPS, Model: BaseLSTM, TP: 0, TN: 30, FP: 0, FN: 29
# Company: UTX, Model: BaseRNN, Epoch [10/120], Loss: 0.6929
# Company: UTX, Model: BaseRNN, Epoch [20/120], Loss: 0.6918
# Company: UTX, Model: BaseRNN, Epoch [30/120], Loss: 0.6904
# Company: UTX, Model: BaseRNN, Epoch [40/120], Loss: 0.6876
# Company: UTX, Model: BaseRNN, Epoch [50/120], Loss: 0.6831
# Company: UTX, Model: BaseRNN, Epoch [60/120], Loss: 0.6807
# Company: UTX, Model: BaseRNN, Epoch [70/120], Loss: 0.6791
# Company: UTX, Model: BaseRNN, Epoch [80/120], Loss: 0.6779
# Company: UTX, Model: BaseRNN, Epoch [90/120], Loss: 0.6767
# Company: UTX, Model: BaseRNN, Epoch [100/120], Loss: 0.6757
# Company: UTX, Model: BaseRNN, Epoch [110/120], Loss: 0.6747
# Company: UTX, Model: BaseRNN, Epoch [120/120], Loss: 0.6737
# Company: UTX, Model: BaseRNN, TP: 10, TN: 19, FP: 14, FN: 16
# Company: UTX, Model: BaseLSTM, Epoch [10/120], Loss: 0.6932
# Company: UTX, Model: BaseLSTM, Epoch [20/120], Loss: 0.6928
# Company: UTX, Model: BaseLSTM, Epoch [30/120], Loss: 0.6919
# Company: UTX, Model: BaseLSTM, Epoch [40/120], Loss: 0.6906
# Company: UTX, Model: BaseLSTM, Epoch [50/120], Loss: 0.6898
# Company: UTX, Model: BaseLSTM, Epoch [60/120], Loss: 0.6891
# Company: UTX, Model: BaseLSTM, Epoch [70/120], Loss: 0.6885
# Company: UTX, Model: BaseLSTM, Epoch [80/120], Loss: 0.6880
# Company: UTX, Model: BaseLSTM, Epoch [90/120], Loss: 0.6872
# Company: UTX, Model: BaseLSTM, Epoch [100/120], Loss: 0.6861
# Company: UTX, Model: BaseLSTM, Epoch [110/120], Loss: 0.6844
# Company: UTX, Model: BaseLSTM, Epoch [120/120], Loss: 0.6821
# Company: UTX, Model: BaseLSTM, TP: 6, TN: 20, FP: 13, FN: 20
# Company: V, Model: BaseRNN, Epoch [10/120], Loss: 0.6922
# Company: V, Model: BaseRNN, Epoch [20/120], Loss: 0.6914
# Company: V, Model: BaseRNN, Epoch [30/120], Loss: 0.6905
# Company: V, Model: BaseRNN, Epoch [40/120], Loss: 0.6896
# Company: V, Model: BaseRNN, Epoch [50/120], Loss: 0.6887
# Company: V, Model: BaseRNN, Epoch [60/120], Loss: 0.6878
# Company: V, Model: BaseRNN, Epoch [70/120], Loss: 0.6871
# Company: V, Model: BaseRNN, Epoch [80/120], Loss: 0.6864
# Company: V, Model: BaseRNN, Epoch [90/120], Loss: 0.6859
# Company: V, Model: BaseRNN, Epoch [100/120], Loss: 0.6854
# Company: V, Model: BaseRNN, Epoch [110/120], Loss: 0.6850
# Company: V, Model: BaseRNN, Epoch [120/120], Loss: 0.6846
# Company: V, Model: BaseRNN, TP: 4, TN: 27, FP: 2, FN: 26
# Company: V, Model: BaseLSTM, Epoch [10/120], Loss: 0.6927
# Company: V, Model: BaseLSTM, Epoch [20/120], Loss: 0.6925
# Company: V, Model: BaseLSTM, Epoch [30/120], Loss: 0.6924
# Company: V, Model: BaseLSTM, Epoch [40/120], Loss: 0.6920
# Company: V, Model: BaseLSTM, Epoch [50/120], Loss: 0.6915
# Company: V, Model: BaseLSTM, Epoch [60/120], Loss: 0.6908
# Company: V, Model: BaseLSTM, Epoch [70/120], Loss: 0.6899
# Company: V, Model: BaseLSTM, Epoch [80/120], Loss: 0.6889
# Company: V, Model: BaseLSTM, Epoch [90/120], Loss: 0.6879
# Company: V, Model: BaseLSTM, Epoch [100/120], Loss: 0.6870
# Company: V, Model: BaseLSTM, Epoch [110/120], Loss: 0.6862
# Company: V, Model: BaseLSTM, Epoch [120/120], Loss: 0.6857
# Company: V, Model: BaseLSTM, TP: 7, TN: 27, FP: 2, FN: 23
# Company: VZ, Model: BaseRNN, Epoch [10/120], Loss: 0.6903
# Company: VZ, Model: BaseRNN, Epoch [20/120], Loss: 0.6874
# Company: VZ, Model: BaseRNN, Epoch [30/120], Loss: 0.6862
# Company: VZ, Model: BaseRNN, Epoch [40/120], Loss: 0.6855
# Company: VZ, Model: BaseRNN, Epoch [50/120], Loss: 0.6848
# Company: VZ, Model: BaseRNN, Epoch [60/120], Loss: 0.6841
# Company: VZ, Model: BaseRNN, Epoch [70/120], Loss: 0.6833
# Company: VZ, Model: BaseRNN, Epoch [80/120], Loss: 0.6824
# Company: VZ, Model: BaseRNN, Epoch [90/120], Loss: 0.6815
# Company: VZ, Model: BaseRNN, Epoch [100/120], Loss: 0.6805
# Company: VZ, Model: BaseRNN, Epoch [110/120], Loss: 0.6796
# Company: VZ, Model: BaseRNN, Epoch [120/120], Loss: 0.6785
# Company: VZ, Model: BaseRNN, TP: 0, TN: 28, FP: 0, FN: 31
# Company: VZ, Model: BaseLSTM, Epoch [10/120], Loss: 0.6906
# Company: VZ, Model: BaseLSTM, Epoch [20/120], Loss: 0.6878
# Company: VZ, Model: BaseLSTM, Epoch [30/120], Loss: 0.6860
# Company: VZ, Model: BaseLSTM, Epoch [40/120], Loss: 0.6847
# Company: VZ, Model: BaseLSTM, Epoch [50/120], Loss: 0.6841
# Company: VZ, Model: BaseLSTM, Epoch [60/120], Loss: 0.6837
# Company: VZ, Model: BaseLSTM, Epoch [70/120], Loss: 0.6833
# Company: VZ, Model: BaseLSTM, Epoch [80/120], Loss: 0.6828
# Company: VZ, Model: BaseLSTM, Epoch [90/120], Loss: 0.6822
# Company: VZ, Model: BaseLSTM, Epoch [100/120], Loss: 0.6812
# Company: VZ, Model: BaseLSTM, Epoch [110/120], Loss: 0.6799
# Company: VZ, Model: BaseLSTM, Epoch [120/120], Loss: 0.6784
# Company: VZ, Model: BaseLSTM, TP: 0, TN: 28, FP: 0, FN: 31
# Company: WFC, Model: BaseRNN, Epoch [10/120], Loss: 0.6858
# Company: WFC, Model: BaseRNN, Epoch [20/120], Loss: 0.6834
# Company: WFC, Model: BaseRNN, Epoch [30/120], Loss: 0.6791
# Company: WFC, Model: BaseRNN, Epoch [40/120], Loss: 0.6762
# Company: WFC, Model: BaseRNN, Epoch [50/120], Loss: 0.6742
# Company: WFC, Model: BaseRNN, Epoch [60/120], Loss: 0.6724
# Company: WFC, Model: BaseRNN, Epoch [70/120], Loss: 0.6711
# Company: WFC, Model: BaseRNN, Epoch [80/120], Loss: 0.6701
# Company: WFC, Model: BaseRNN, Epoch [90/120], Loss: 0.6693
# Company: WFC, Model: BaseRNN, Epoch [100/120], Loss: 0.6685
# Company: WFC, Model: BaseRNN, Epoch [110/120], Loss: 0.6679
# Company: WFC, Model: BaseRNN, Epoch [120/120], Loss: 0.6673
# Company: WFC, Model: BaseRNN, TP: 22, TN: 8, FP: 23, FN: 6
# Company: WFC, Model: BaseLSTM, Epoch [10/120], Loss: 0.6875
# Company: WFC, Model: BaseLSTM, Epoch [20/120], Loss: 0.6863
# Company: WFC, Model: BaseLSTM, Epoch [30/120], Loss: 0.6858
# Company: WFC, Model: BaseLSTM, Epoch [40/120], Loss: 0.6852
# Company: WFC, Model: BaseLSTM, Epoch [50/120], Loss: 0.6843
# Company: WFC, Model: BaseLSTM, Epoch [60/120], Loss: 0.6833
# Company: WFC, Model: BaseLSTM, Epoch [70/120], Loss: 0.6821
# Company: WFC, Model: BaseLSTM, Epoch [80/120], Loss: 0.6807
# Company: WFC, Model: BaseLSTM, Epoch [90/120], Loss: 0.6788
# Company: WFC, Model: BaseLSTM, Epoch [100/120], Loss: 0.6754
# Company: WFC, Model: BaseLSTM, Epoch [110/120], Loss: 0.6695
# Company: WFC, Model: BaseLSTM, Epoch [120/120], Loss: 0.6636
# Company: WFC, Model: BaseLSTM, TP: 25, TN: 10, FP: 21, FN: 3
# Company: WMT, Model: BaseRNN, Epoch [10/120], Loss: 0.6936
# Company: WMT, Model: BaseRNN, Epoch [20/120], Loss: 0.6935
# Company: WMT, Model: BaseRNN, Epoch [30/120], Loss: 0.6934
# Company: WMT, Model: BaseRNN, Epoch [40/120], Loss: 0.6933
# Company: WMT, Model: BaseRNN, Epoch [50/120], Loss: 0.6931
# Company: WMT, Model: BaseRNN, Epoch [60/120], Loss: 0.6930
# Company: WMT, Model: BaseRNN, Epoch [70/120], Loss: 0.6927
# Company: WMT, Model: BaseRNN, Epoch [80/120], Loss: 0.6924
# Company: WMT, Model: BaseRNN, Epoch [90/120], Loss: 0.6920
# Company: WMT, Model: BaseRNN, Epoch [100/120], Loss: 0.6915
# Company: WMT, Model: BaseRNN, Epoch [110/120], Loss: 0.6911
# Company: WMT, Model: BaseRNN, Epoch [120/120], Loss: 0.6908
# Company: WMT, Model: BaseRNN, TP: 10, TN: 17, FP: 14, FN: 18
# Company: WMT, Model: BaseLSTM, Epoch [10/120], Loss: 0.6934
# Company: WMT, Model: BaseLSTM, Epoch [20/120], Loss: 0.6933
# Company: WMT, Model: BaseLSTM, Epoch [30/120], Loss: 0.6933
# Company: WMT, Model: BaseLSTM, Epoch [40/120], Loss: 0.6933
# Company: WMT, Model: BaseLSTM, Epoch [50/120], Loss: 0.6933
# Company: WMT, Model: BaseLSTM, Epoch [60/120], Loss: 0.6932
# Company: WMT, Model: BaseLSTM, Epoch [70/120], Loss: 0.6932
# Company: WMT, Model: BaseLSTM, Epoch [80/120], Loss: 0.6932
# Company: WMT, Model: BaseLSTM, Epoch [90/120], Loss: 0.6932
# Company: WMT, Model: BaseLSTM, Epoch [100/120], Loss: 0.6932
# Company: WMT, Model: BaseLSTM, Epoch [110/120], Loss: 0.6932
# Company: WMT, Model: BaseLSTM, Epoch [120/120], Loss: 0.6931
# Company: WMT, Model: BaseLSTM, TP: 24, TN: 7, FP: 24, FN: 4
# Company: XOM, Model: BaseRNN, Epoch [10/120], Loss: 0.6906
# Company: XOM, Model: BaseRNN, Epoch [20/120], Loss: 0.6897
# Company: XOM, Model: BaseRNN, Epoch [30/120], Loss: 0.6881
# Company: XOM, Model: BaseRNN, Epoch [40/120], Loss: 0.6856
# Company: XOM, Model: BaseRNN, Epoch [50/120], Loss: 0.6812
# Company: XOM, Model: BaseRNN, Epoch [60/120], Loss: 0.6754
# Company: XOM, Model: BaseRNN, Epoch [70/120], Loss: 0.6729
# Company: XOM, Model: BaseRNN, Epoch [80/120], Loss: 0.6710
# Company: XOM, Model: BaseRNN, Epoch [90/120], Loss: 0.6692
# Company: XOM, Model: BaseRNN, Epoch [100/120], Loss: 0.6674
# Company: XOM, Model: BaseRNN, Epoch [110/120], Loss: 0.6657
# Company: XOM, Model: BaseRNN, Epoch [120/120], Loss: 0.6639
# Company: XOM, Model: BaseRNN, TP: 3, TN: 28, FP: 5, FN: 23
# Company: XOM, Model: BaseLSTM, Epoch [10/120], Loss: 0.6911
# Company: XOM, Model: BaseLSTM, Epoch [20/120], Loss: 0.6908
# Company: XOM, Model: BaseLSTM, Epoch [30/120], Loss: 0.6905
# Company: XOM, Model: BaseLSTM, Epoch [40/120], Loss: 0.6898
# Company: XOM, Model: BaseLSTM, Epoch [50/120], Loss: 0.6873
# Company: XOM, Model: BaseLSTM, Epoch [60/120], Loss: 0.6845
# Company: XOM, Model: BaseLSTM, Epoch [70/120], Loss: 0.6831
# Company: XOM, Model: BaseLSTM, Epoch [80/120], Loss: 0.6816
# Company: XOM, Model: BaseLSTM, Epoch [90/120], Loss: 0.6799
# Company: XOM, Model: BaseLSTM, Epoch [100/120], Loss: 0.6786
# Company: XOM, Model: BaseLSTM, Epoch [110/120], Loss: 0.6781
# Company: XOM, Model: BaseLSTM, Epoch [120/120], Loss: 0.6772
# Company: XOM, Model: BaseLSTM, TP: 1, TN: 33, FP: 0, FN: 25
# Evaluation complete
#           Average Accuracy  Average MACC
# BaseRNN           0.512761      0.033881
# BaseLSTM          0.515293      0.037919
