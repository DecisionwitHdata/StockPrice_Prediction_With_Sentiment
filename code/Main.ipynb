# %% [markdown]
# ## Stock Prediction Notebook(Main Models)
# This notebook demonstrates stock price prediction using data with sentiment analysis. It covers data preparation, model definition, training, and evaluation.

# %%
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import requests
import zipfile
import os
from io import BytesIO

# %% [markdown]
# ### Data Preparation
# Classes and functions for loading and preprocessing data.

# %%
url = 'https://github.com/yumoxu/stocknet-dataset/archive/refs/heads/master.zip'

response = requests.get(url)
zip_file = zipfile.ZipFile(BytesIO(response.content))

price_folder_path = 'stocknet-dataset-master/price/raw/'

data_frames = []
for file_name in zip_file.namelist():
    if file_name.startswith(price_folder_path) and file_name.endswith('.csv'):
        # 주식 이름을 파일명에서 추출 (예: 'raw/prices/appl.csv' -> 'appl')
        stock_name = os.path.splitext(os.path.basename(file_name))[0]

        # CSV 파일을 읽어 데이터프레임으로 변환
        with zip_file.open(file_name) as file:  
            df = pd.read_csv(file)
            # 주식 이름 열 추가
            df['Stock'] = stock_name
            df['Date'] = pd.to_datetime(df['Date'])
            # df.set_index('Date', inplace=True)
            data_frames.append(df)

combined_df = pd.concat(data_frames, ignore_index=False)

class AddStockDataset(Dataset):
    def __init__(self, data, seq_length, sentiment_data):
        self.data = data
        self.seq_length = seq_length
        self.features = data[['Open', 'High', 'Low', 'Volume', 'Adj Close', 'Close']].values
        self.labels = data['movement'].values
        self.sentiment_data = sentiment_data[['positive', 'neutral', 'negative']].values

    def __len__(self):
        return len(self.data) - self.seq_length

    def __getitem__(self, idx):
        x = self.features[idx:idx+self.seq_length]
        y = self.labels[idx+self.seq_length]
        sentiment = self.sentiment_data[idx+self.seq_length]

        x = torch.tensor(x, dtype=torch.float32)
        y = torch.tensor(y, dtype=torch.long)
        sentiment = torch.tensor(sentiment, dtype=torch.float32)

# %% [markdown]
# ### Model Definition
# Definitions for stock price prediction models using Stock Price + Sentiment Model

# %%
class StockRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, sentiment_size, num_layers, dropout=0.0):
        super(StockRNN, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.dropout = nn.Dropout(dropout)  # Dropout layer
        self.fc = nn.Linear(hidden_size + sentiment_size, output_size)

    def forward(self, x, sentiment_data):
        h0 = torch.zeros(self.rnn.num_layers, x.size(0), self.rnn.hidden_size).to(x.device)
        out, hn = self.rnn(x, h0)
        last_hidden = hn[-1]
        last_hidden = self.dropout(last_hidden)  # Apply dropout
        sentiment_data = sentiment_data.view(sentiment_data.size(0), -1)
        combined = torch.cat((last_hidden, sentiment_data), dim=1)
        output = self.fc(combined)
        return output


class StockLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, sentiment_size, num_layers, dropout=0.0):
        super(StockLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.dropout = nn.Dropout(dropout)  # Dropout layer
        self.fc = nn.Linear(hidden_size + sentiment_size, output_size)

    def forward(self, x, sentiment_data):
        h0 = torch.zeros(self.lstm.num_layers, x.size(0), self.lstm.hidden_size).to(x.device)
        c0 = torch.zeros(self.lstm.num_layers, x.size(0), self.lstm.hidden_size).to(x.device)
        out, (hn, _) = self.lstm(x, (h0, c0))
        
        # Apply dropout to the LSTM outputs (last hidden state)
        last_hidden = self.dropout(hn[-1])

        sentiment_data = sentiment_data.view(sentiment_data.size(0), -1)
        combined = torch.cat((last_hidden, sentiment_data), dim=1)

        output = self.fc(combined)
        return output
    
class SentimentRNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout=0.0):
        super(SentimentRNN, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.layer_norm = nn.LayerNorm(hidden_size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        h0 = torch.zeros(self.rnn.num_layers, x.size(0), self.rnn.hidden_size).to(x.device)
        out, hn = self.rnn(x, h0)
        out = self.layer_norm(out)
        out = self.dropout(out)  # Apply dropout after normalization
        return hn[-1]  # Return the last hidden state


class StockSentimentRNN(nn.Module):
    def __init__(self, stock_input_size, sentiment_input_size, hidden_size, output_size, num_layers, dropout=0.0):
        super(StockSentimentRNN, self).__init__()
        self.stock_rnn = nn.RNN(stock_input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.stock_layer_norm = nn.LayerNorm(hidden_size)
        self.sentiment_rnn = SentimentRNN(sentiment_input_size, hidden_size, num_layers, dropout=dropout)
        self.dropout = nn.Dropout(dropout)  # Add dropout after concatenation
        self.fc = nn.Linear(hidden_size * 2, output_size)  # No Sigmoid for CrossEntropyLoss

    def forward(self, data, sentiment_data):
        # Stock data processing
        h0_stock = torch.zeros(self.stock_rnn.num_layers, data.size(0), self.stock_rnn.hidden_size).to(data.device)
        stock_out, stock_hn = self.stock_rnn(data, h0_stock)
        stock_out = self.stock_layer_norm(stock_out)  # Normalize stock RNN output
        stock_out = self.dropout(stock_out)  # Apply dropout to the stock output
        stock_hidden = stock_hn[-1]  # Get the last hidden state from the stock RNN

        # Sentiment data processing
        seq_length = data.size(1)  # Get sequence length from stock data
        sentiment_data = sentiment_data.unsqueeze(1).repeat(1, seq_length, 1)  # Repeat sentiment data
        sentiment_out = self.sentiment_rnn(sentiment_data)  # Process sentiment data and get last hidden state

        # Concatenate hidden states from stock and sentiment RNNs
        combined_hidden = torch.cat((stock_hidden, sentiment_out), dim=1)

        # Apply dropout to the combined hidden state
        combined_hidden = self.dropout(combined_hidden)

        # Pass the combined hidden state through a fully connected layer
        output = self.fc(combined_hidden)
        return output

# %% [markdown]
# ### Logging Setup and Utilities

# %%
import logging
logging.basicConfig(filename='sentimodel_training_log.txt', level=logging.INFO)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class ModelHandler:
    def __init__(self, model, criterion, optimizer, num_epochs, device):
        self.model = model
        self.criterion = criterion
        self.optimizer = optimizer
        self.num_epochs = num_epochs
        self.device = device

    def train(self, train_loader, company_id, model_name):
        self.model.to(self.device)
        self.model.train()
        
        for epoch in range(self.num_epochs):
            total_loss = 0.0
            for data, labels, sentiment_data in train_loader:
                # Move data to the appropriate device
                data = data.to(self.device)
                labels = labels.to(self.device)
                sentiment_data = sentiment_data.to(self.device)
                
                # Clear gradients
                self.optimizer.zero_grad()

                # Forward pass
                outputs = self.model(data, sentiment_data)
                
                # Compute loss
                loss = self.criterion(outputs, labels)

                # Backward pass and optimization
                loss.backward()
                self.optimizer.step()
                
                total_loss += loss.item()
            
            avg_loss = total_loss / len(train_loader)
            if (epoch + 1) % 10 == 0:
                log_message = (f'Company: {company_id}, Model: {model_name}, '
                               f'Epoch [{epoch+1}/{self.num_epochs}], '
                               f'Average Loss: {avg_loss:.4f}')
                logging.info(log_message)
                print(log_message)

    def evaluate(self, test_loader, company_id, model_name):
        self.model.to(self.device)
        self.model.eval()
        correct = 0
        total = 0
        tp = tn = fp = fn = 0  # Initialize counters
        
        with torch.no_grad():
            for data, labels, sentiment_data in test_loader:
                # Move data to the appropriate device
                data = data.to(self.device)
                labels = labels.to(self.device)
                sentiment_data = sentiment_data.to(self.device)
                
                # Forward pass
                outputs = self.model(data, sentiment_data)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                # Calculate TP, TN, FP, FN
                tp += ((predicted == 1) & (labels == 1)).sum().item()
                tn += ((predicted == 0) & (labels == 0)).sum().item()
                fp += ((predicted == 1) & (labels == 0)).sum().item()
                fn += ((predicted == 0) & (labels == 1)).sum().item()

        accuracy = correct / total
        macc = self.calculate_mcc(tp, tn, fp, fn)

        # Log and print evaluation results
        log_message = (f'Company: {company_id}, Model: {model_name}, '
                       f'Accuracy: {accuracy:.4f}, MCC: {macc:.4f}, '
                       f'TP: {tp}, TN: {tn}, FP: {fp}, FN: {fn}')
        logging.info(log_message)
        print(log_message)
        return accuracy, macc

    def calculate_mcc(self, tp, tn, fp, fn):
        numerator = (tp * tn) - (fp * fn)
        denominator = ((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) ** 0.5
        if denominator == 0:
            return 0
        else:
            return numerator / denominator

# %% [markdown]
# ### Training and Hyperparameter Tuning
# Training scripts and hyperparameter optimization using Optuna.

# %%
pip install optuna
import optuna
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import accuracy_score

# Load your data
filtered = pd.read_csv(r'C:\Users\dhjrz\nlp\ionlab\price_scaled.csv')
senti = pd.read_csv(r"C:\Users\dhjrz\nlp\ionlab\all_companies_sentiment.csv")
selected_columns = ['filename', 'label', 'positive', 'negative', 'neutral', 'sentiment_score']
sentiment = senti[selected_columns]
sentiment.rename(columns={'filename': 'Date'}, inplace=True)
sentiment['Date'] = pd.to_datetime(sentiment['Date'])
data = filtered.copy()
sentiment_data = sentiment.copy()
companies_senti = filtered['Stock'].unique().tolist()


import optuna
import torch
import torch.nn as nn
import torch.optim as optim

# Make sure to define your Dataset, Models, and ModelHandler as before

def get_data_loaders(company_id, seq_length, sentiment_data):
    # Function to create data loaders based on the company_id
    # Replace with your actual implementation
    train_data = filtered[(filtered['Stock'] == company_id) & 
                          (filtered['Date'] >= '2014-01-01') & 
                          (filtered['Date'] < '2015-08-01')]
    
    valid_data = filtered[(filtered['Stock'] == company_id) & 
                          (filtered['Date'] >= '2015-08-01') & 
                          (filtered['Date'] < '2015-10-01')]
    
    test_data = filtered[(filtered['Stock'] == company_id) & 
                         (filtered['Date'] >= '2015-10-01') & 
                         (filtered['Date'] < '2016-01-01')]

    train_dataset = AddStockDataset(train_data, seq_length, sentiment_data)
    valid_dataset = AddStockDataset(valid_data, seq_length, sentiment_data)
    test_dataset = AddStockDataset(test_data, seq_length, sentiment_data)
    
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    return train_loader, test_loader

def objective(trial):
    hidden_size = trial.suggest_categorical('hidden_size', [32, 64])
    num_layers = trial.suggest_int('num_layers', 1, 2)
    dropout = trial.suggest_uniform('dropout', 0.0, 0.5)
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
    model_type = trial.suggest_categorical('model_type', ['StockRNN', 'StockLSTM', 'StockSentimentRNN'])
    
    # You can also include model initialization and hyperparameter selection based on your requirement
    if model_type == 'StockRNN':
        model = StockRNN(input_size=6, hidden_size=hidden_size, output_size=2, sentiment_size=3, num_layers=num_layers, dropout=dropout)
    elif model_type == 'StockLSTM':
        model = StockLSTM(input_size=6, hidden_size=hidden_size, output_size=2, sentiment_size=3, num_layers=num_layers, dropout=dropout)
    else:
        model = StockSentimentRNN(stock_input_size=6, sentiment_input_size=3, hidden_size=hidden_size, output_size=2, num_layers=num_layers, dropout=dropout)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Example of using multiple companies; adjust the list as needed
    companies = companies_senti.copy()
    avg_accuracy = 0
    avg_mcc = 0
    num_companies = len(companies)

    for company_id in companies:
        train_loader, test_loader = get_data_loaders(company_id, seq_length=5, sentiment_data=sentiment)
        
        # Initialize ModelHandler with only the current trial's model, criterion, and optimizer
        model_handler = ModelHandler(models=[model], criteria=[criterion], optimizers=[optimizer], num_epochs=10, device=device)
        
        # Train and evaluate
        model_handler.train_and_evaluate(train_loader, test_loader, company_id)
        accuracy, mcc = model_handler.evaluate(test_loader, company_id, model_type, model)

        avg_accuracy += accuracy
        avg_mcc += mcc

    # Calculate average metrics
    avg_accuracy /= num_companies
    avg_mcc /= num_companies

    # Define weights for accuracy and MCC
    accuracy_weight = 0.3
    mcc_weight = 0.7

    # Combine them into a single objective
    combined_score = accuracy_weight * avg_accuracy + mcc_weight * avg_mcc

    return combined_score

def run_optuna_study():
    study = optuna.create_study(direction='maximize')
    study.optimize(objective, n_trials=50)  # Number of trials can be adjusted

    print("Best hyperparameters: ", study.best_params)
    print("Best value: ", study.best_value)

if __name__ == '__main__':
    run_optuna_study()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import pandas as pd

filtered = pd.read_csv(r'C:\Users\dhjrz\nlp\ionlab\price_scaled.csv')
companies = filtered['Stock'].unique().tolist()

senti = pd.read_csv(r'C:\Users\dhjrz\nlp\ionlab\all_companies_sentiment.csv')
selected_columns = ['filename','label','positive','negative','neutral', 'sentiment_score']
sentiment = senti[selected_columns]
sentiment.rename(columns={'filename':'Date'}, inplace=True)
sentiment['Date'] = pd.to_datetime(sentiment['Date'])

data = filtered.copy()
sentiment_data = sentiment.copy()

num_layers = 2
input_size = 6
hidden_size = 64
output_size = 2  # 1 또는 0
sentiment_size = 3
dropout = 0.1
stock_input_size = 6       # 주가 데이터의 feature 수
seq_length = 5 #5일치로 하루 예측
num_epochs = 120
lr = 0.00001


def run_sentimodels_on_companies(companies_senti, seq_length, num_epochs):
    company_results = {}
    models = [StockRNN, StockLSTM, StockSentimentRNN]  # Add your models here
    
    # Dictionary to store cumulative accuracy and macc for each model
    model_metrics = {model_cls.__name__: {'accuracy': 0, 'macc': 0, 'count': 0} for model_cls in models}


    # Initialize device
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    for company_id in companies_senti:
        print(f"Processing company: {company_id}")

        # Assuming train_data and test_data are available for each company
        train_data = filtered[(filtered['Stock'] == company_id) & 
                              (filtered['Date'] >= '2014-01-01') & 
                              (filtered['Date'] < '2015-08-01')]
        
        valid_data = filtered[(filtered['Stock'] == company_id) & 
                              (filtered['Date'] >= '2015-08-01') & 
                              (filtered['Date'] < '2015-10-01')]
        
        test_data = filtered[(filtered['Stock'] == company_id) & 
                             (filtered['Date'] >= '2015-10-01') & 
                             (filtered['Date'] < '2016-01-01')]

        train_dataset = AddStockDataset(train_data, seq_length, sentiment_data)
        valid_dataset = AddStockDataset(valid_data, seq_length, sentiment_data)
        test_dataset = AddStockDataset(test_data, seq_length, sentiment_data)
        
        train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False)
        valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=False)
        test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

        for model_cls in models:
            print(f"Training model: {model_cls.__name__}")

            if model_cls == StockRNN or model_cls == StockLSTM:
                # These models don't require sentiment_input_size
                model = model_cls(input_size=6, hidden_size=hidden_size, output_size=2, sentiment_size=3, num_layers=num_layers, dropout=dropout)
                
            elif model_cls == StockSentimentRNN:
                # StockSentimentRNN requires both stock and sentiment input sizes
                model = model_cls(stock_input_size=6, sentiment_input_size=3, hidden_size=hidden_size, output_size=2, num_layers=num_layers, dropout=dropout)
            
            model.to(device)  # Move model to the device
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=0.001)

            handler = ModelHandler(model, criterion, optimizer, num_epochs, device)

            # Train and evaluate
            handler.train(train_loader, company_id, model_cls.__name__)
            accuracy, macc = handler.evaluate(test_loader, company_id, model_cls.__name__)

            model_name = model_cls.__name__
            company_results[(company_id, model_name)] = {'Accuracy': accuracy, 'MACC': macc}

            # Add accuracy and macc to the cumulative sum for the model
            model_metrics[model_name]['accuracy'] += accuracy
            model_metrics[model_name]['macc'] += macc
            model_metrics[model_name]['count'] += 1  # Track number of companies processed

            # Store results
            company_results[(company_id, model_cls.__name__)] = {'Accuracy': accuracy, 'MACC': macc}

            # Add accuracy and macc to the cumulative sum for the model
            model_metrics[model_name]['accuracy'] += accuracy
            model_metrics[model_name]['macc'] += macc
            model_metrics[model_name]['count'] += 1  # Track number of companies processed

            
             # Calculate average accuracy and macc for each model

    avg_results = {}
    for model_name, metrics in model_metrics.items():
        avg_accuracy = metrics['accuracy'] / metrics['count']
        avg_macc = metrics['macc'] / metrics['count']
        avg_results[model_name] = {'Average Accuracy': avg_accuracy, 'Average MACC': avg_macc}
    
    # Save results of all companies
    results_df = pd.DataFrame.from_dict(company_results, orient='index')
    results_df.to_csv('company88_Senti_results.csv')

    # Save average results of models
    avg_results_df = pd.DataFrame.from_dict(avg_results, orient='index')
    avg_results_df.to_csv('average_Senti_results.csv')

    print("Evaluation complete")
    print(avg_results_df)


    
# Assuming `companies` is defined
companies_senti = companies.copy()

run_sentimodels_on_companies(companies_senti, seq_length=5, num_epochs=120)
# Out:
# C:\Users\dhjrz\AppData\Local\Temp\ipykernel_10648\3143223908.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentiment.rename(columns={'filename':'Date'}, inplace=True)
# C:\Users\dhjrz\AppData\Local\Temp\ipykernel_10648\3143223908.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentiment['Date'] = pd.to_datetime(sentiment['Date'])
# Processing company: AAPL
# Training model: StockRNN
# Company: AAPL, Model: StockRNN, Epoch [10/120], Average Loss: 0.6889
# Company: AAPL, Model: StockRNN, Epoch [20/120], Average Loss: 0.6851
# Company: AAPL, Model: StockRNN, Epoch [30/120], Average Loss: 0.6833
# Company: AAPL, Model: StockRNN, Epoch [40/120], Average Loss: 0.6806
# Company: AAPL, Model: StockRNN, Epoch [50/120], Average Loss: 0.6798
# Company: AAPL, Model: StockRNN, Epoch [60/120], Average Loss: 0.6740
# Company: AAPL, Model: StockRNN, Epoch [70/120], Average Loss: 0.6751
# Company: AAPL, Model: StockRNN, Epoch [80/120], Average Loss: 0.6697
# Company: AAPL, Model: StockRNN, Epoch [90/120], Average Loss: 0.6692
# Company: AAPL, Model: StockRNN, Epoch [100/120], Average Loss: 0.6669
# Company: AAPL, Model: StockRNN, Epoch [110/120], Average Loss: 0.6676
# Company: AAPL, Model: StockRNN, Epoch [120/120], Average Loss: 0.6656
# Company: AAPL, Model: StockRNN, Accuracy: 0.6102, MCC: 0.2818, TP: 19, TN: 17, FP: 18, FN: 5
# Training model: StockLSTM
# Company: AAPL, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6861
# Company: AAPL, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6824
# Company: AAPL, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6811
# Company: AAPL, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6796
# Company: AAPL, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6800
# Company: AAPL, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6787
# Company: AAPL, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6788
# Company: AAPL, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6789
# Company: AAPL, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6765
# Company: AAPL, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6770
# Company: AAPL, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6767
# Company: AAPL, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6754
# Company: AAPL, Model: StockLSTM, Accuracy: 0.5593, MCC: 0.2221, TP: 20, TN: 13, FP: 22, FN: 4
# Training model: StockSentimentRNN
# Company: AAPL, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6873
# Company: AAPL, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6846
# Company: AAPL, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6820
# Company: AAPL, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6813
# Company: AAPL, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6781
# Company: AAPL, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6747
# Company: AAPL, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6707
# Company: AAPL, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6725
# Company: AAPL, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6685
# Company: AAPL, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6641
# Company: AAPL, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6587
# Company: AAPL, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6594
# Company: AAPL, Model: StockSentimentRNN, Accuracy: 0.6102, MCC: 0.2818, TP: 19, TN: 17, FP: 18, FN: 5
# Processing company: ABB
# Training model: StockRNN
# Company: ABB, Model: StockRNN, Epoch [10/120], Average Loss: 0.6876
# Company: ABB, Model: StockRNN, Epoch [20/120], Average Loss: 0.6750
# Company: ABB, Model: StockRNN, Epoch [30/120], Average Loss: 0.6743
# Company: ABB, Model: StockRNN, Epoch [40/120], Average Loss: 0.6708
# Company: ABB, Model: StockRNN, Epoch [50/120], Average Loss: 0.6688
# Company: ABB, Model: StockRNN, Epoch [60/120], Average Loss: 0.6698
# Company: ABB, Model: StockRNN, Epoch [70/120], Average Loss: 0.6700
# Company: ABB, Model: StockRNN, Epoch [80/120], Average Loss: 0.6698
# Company: ABB, Model: StockRNN, Epoch [90/120], Average Loss: 0.6695
# Company: ABB, Model: StockRNN, Epoch [100/120], Average Loss: 0.6652
# Company: ABB, Model: StockRNN, Epoch [110/120], Average Loss: 0.6647
# Company: ABB, Model: StockRNN, Epoch [120/120], Average Loss: 0.6609
# Company: ABB, Model: StockRNN, Accuracy: 0.5254, MCC: 0.0331, TP: 20, TN: 11, FP: 16, FN: 12
# Training model: StockLSTM
# Company: ABB, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6910
# Company: ABB, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6894
# Company: ABB, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6848
# Company: ABB, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6810
# Company: ABB, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6787
# Company: ABB, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6791
# Company: ABB, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6770
# Company: ABB, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6738
# Company: ABB, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6673
# Company: ABB, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6646
# Company: ABB, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6648
# Company: ABB, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6556
# Company: ABB, Model: StockLSTM, Accuracy: 0.5424, MCC: 0.1064, TP: 14, TN: 18, FP: 9, FN: 18
# Training model: StockSentimentRNN
# Company: ABB, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6845
# Company: ABB, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6736
# Company: ABB, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6725
# Company: ABB, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6735
# Company: ABB, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6605
# Company: ABB, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6684
# Company: ABB, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6504
# Company: ABB, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6541
# Company: ABB, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6623
# Company: ABB, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6571
# Company: ABB, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6522
# Company: ABB, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6558
# Company: ABB, Model: StockSentimentRNN, Accuracy: 0.5593, MCC: 0.0887, TP: 25, TN: 8, FP: 19, FN: 7
# Processing company: ABBV
# Training model: StockRNN
# Company: ABBV, Model: StockRNN, Epoch [10/120], Average Loss: 0.6857
# Company: ABBV, Model: StockRNN, Epoch [20/120], Average Loss: 0.6874
# Company: ABBV, Model: StockRNN, Epoch [30/120], Average Loss: 0.6849
# Company: ABBV, Model: StockRNN, Epoch [40/120], Average Loss: 0.6799
# Company: ABBV, Model: StockRNN, Epoch [50/120], Average Loss: 0.6776
# Company: ABBV, Model: StockRNN, Epoch [60/120], Average Loss: 0.6772
# Company: ABBV, Model: StockRNN, Epoch [70/120], Average Loss: 0.6741
# Company: ABBV, Model: StockRNN, Epoch [80/120], Average Loss: 0.6630
# Company: ABBV, Model: StockRNN, Epoch [90/120], Average Loss: 0.6700
# Company: ABBV, Model: StockRNN, Epoch [100/120], Average Loss: 0.6680
# Company: ABBV, Model: StockRNN, Epoch [110/120], Average Loss: 0.6640
# Company: ABBV, Model: StockRNN, Epoch [120/120], Average Loss: 0.6558
# Company: ABBV, Model: StockRNN, Accuracy: 0.6102, MCC: 0.3202, TP: 31, TN: 5, FP: 23, FN: 0
# Training model: StockLSTM
# Company: ABBV, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6875
# Company: ABBV, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6858
# Company: ABBV, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6845
# Company: ABBV, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6825
# Company: ABBV, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6804
# Company: ABBV, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6804
# Company: ABBV, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6796
# Company: ABBV, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6796
# Company: ABBV, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6787
# Company: ABBV, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6780
# Company: ABBV, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6777
# Company: ABBV, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6792
# Company: ABBV, Model: StockLSTM, Accuracy: 0.5254, MCC: 0.0095, TP: 30, TN: 1, FP: 27, FN: 1
# Training model: StockSentimentRNN
# Company: ABBV, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6898
# Company: ABBV, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6866
# Company: ABBV, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6853
# Company: ABBV, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6850
# Company: ABBV, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6796
# Company: ABBV, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6787
# Company: ABBV, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6793
# Company: ABBV, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6670
# Company: ABBV, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6681
# Company: ABBV, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6680
# Company: ABBV, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6661
# Company: ABBV, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6652
# Company: ABBV, Model: StockSentimentRNN, Accuracy: 0.5763, MCC: 0.1467, TP: 25, TN: 9, FP: 19, FN: 6
# Processing company: AEP
# Training model: StockRNN
# Company: AEP, Model: StockRNN, Epoch [10/120], Average Loss: 0.6740
# Company: AEP, Model: StockRNN, Epoch [20/120], Average Loss: 0.6718
# Company: AEP, Model: StockRNN, Epoch [30/120], Average Loss: 0.6691
# Company: AEP, Model: StockRNN, Epoch [40/120], Average Loss: 0.6625
# Company: AEP, Model: StockRNN, Epoch [50/120], Average Loss: 0.6623
# Company: AEP, Model: StockRNN, Epoch [60/120], Average Loss: 0.6587
# Company: AEP, Model: StockRNN, Epoch [70/120], Average Loss: 0.6555
# Company: AEP, Model: StockRNN, Epoch [80/120], Average Loss: 0.6499
# Company: AEP, Model: StockRNN, Epoch [90/120], Average Loss: 0.6510
# Company: AEP, Model: StockRNN, Epoch [100/120], Average Loss: 0.6456
# Company: AEP, Model: StockRNN, Epoch [110/120], Average Loss: 0.6378
# Company: AEP, Model: StockRNN, Epoch [120/120], Average Loss: 0.6221
# Company: AEP, Model: StockRNN, Accuracy: 0.5254, MCC: -0.0564, TP: 26, TN: 5, FP: 19, FN: 9
# Training model: StockLSTM
# Company: AEP, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6768
# Company: AEP, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6742
# Company: AEP, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6734
# Company: AEP, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6740
# Company: AEP, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6723
# Company: AEP, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6715
# Company: AEP, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6711
# Company: AEP, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6698
# Company: AEP, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6683
# Company: AEP, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6676
# Company: AEP, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6662
# Company: AEP, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6632
# Company: AEP, Model: StockLSTM, Accuracy: 0.6102, MCC: 0.1586, TP: 35, TN: 1, FP: 23, FN: 0
# Training model: StockSentimentRNN
# Company: AEP, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6766
# Company: AEP, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6674
# Company: AEP, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6642
# Company: AEP, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6605
# Company: AEP, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6590
# Company: AEP, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6580
# Company: AEP, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6469
# Company: AEP, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6573
# Company: AEP, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6530
# Company: AEP, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6425
# Company: AEP, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6284
# Company: AEP, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6294
# Company: AEP, Model: StockSentimentRNN, Accuracy: 0.5254, MCC: -0.0099, TP: 23, TN: 8, FP: 16, FN: 12
# Processing company: AGFS
# Training model: StockRNN
# Company: AGFS, Model: StockRNN, Epoch [10/120], Average Loss: 0.6627
# Company: AGFS, Model: StockRNN, Epoch [20/120], Average Loss: 0.6607
# Company: AGFS, Model: StockRNN, Epoch [30/120], Average Loss: 0.6468
# Company: AGFS, Model: StockRNN, Epoch [40/120], Average Loss: 0.6462
# Company: AGFS, Model: StockRNN, Epoch [50/120], Average Loss: 0.6452
# Company: AGFS, Model: StockRNN, Epoch [60/120], Average Loss: 0.6323
# Company: AGFS, Model: StockRNN, Epoch [70/120], Average Loss: 0.6165
# Company: AGFS, Model: StockRNN, Epoch [80/120], Average Loss: 0.6010
# Company: AGFS, Model: StockRNN, Epoch [90/120], Average Loss: 0.5959
# Company: AGFS, Model: StockRNN, Epoch [100/120], Average Loss: 0.5804
# Company: AGFS, Model: StockRNN, Epoch [110/120], Average Loss: 0.5734
# Company: AGFS, Model: StockRNN, Epoch [120/120], Average Loss: 0.5629
# Company: AGFS, Model: StockRNN, Accuracy: 0.4237, MCC: 0.0390, TP: 21, TN: 4, FP: 32, FN: 2
# Training model: StockLSTM
# Company: AGFS, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6621
# Company: AGFS, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6630
# Company: AGFS, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6621
# Company: AGFS, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6626
# Company: AGFS, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6517
# Company: AGFS, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6520
# Company: AGFS, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6608
# Company: AGFS, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6523
# Company: AGFS, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6449
# Company: AGFS, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6423
# Company: AGFS, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6377
# Company: AGFS, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6344
# Company: AGFS, Model: StockLSTM, Accuracy: 0.3729, MCC: -0.1643, TP: 22, TN: 0, FP: 36, FN: 1
# Training model: StockSentimentRNN
# Company: AGFS, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6592
# Company: AGFS, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6646
# Company: AGFS, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6539
# Company: AGFS, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6495
# Company: AGFS, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6409
# Company: AGFS, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6242
# Company: AGFS, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6249
# Company: AGFS, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.5993
# Company: AGFS, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6225
# Company: AGFS, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6028
# Company: AGFS, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.5776
# Company: AGFS, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.5591
# Company: AGFS, Model: StockSentimentRNN, Accuracy: 0.4068, MCC: 0.1050, TP: 23, TN: 1, FP: 35, FN: 0
# Processing company: AMGN
# Training model: StockRNN
# Company: AMGN, Model: StockRNN, Epoch [10/120], Average Loss: 0.6871
# Company: AMGN, Model: StockRNN, Epoch [20/120], Average Loss: 0.6779
# Company: AMGN, Model: StockRNN, Epoch [30/120], Average Loss: 0.6805
# Company: AMGN, Model: StockRNN, Epoch [40/120], Average Loss: 0.6779
# Company: AMGN, Model: StockRNN, Epoch [50/120], Average Loss: 0.6725
# Company: AMGN, Model: StockRNN, Epoch [60/120], Average Loss: 0.6701
# Company: AMGN, Model: StockRNN, Epoch [70/120], Average Loss: 0.6764
# Company: AMGN, Model: StockRNN, Epoch [80/120], Average Loss: 0.6689
# Company: AMGN, Model: StockRNN, Epoch [90/120], Average Loss: 0.6667
# Company: AMGN, Model: StockRNN, Epoch [100/120], Average Loss: 0.6656
# Company: AMGN, Model: StockRNN, Epoch [110/120], Average Loss: 0.6602
# Company: AMGN, Model: StockRNN, Epoch [120/120], Average Loss: 0.6765
# Company: AMGN, Model: StockRNN, Accuracy: 0.5932, MCC: 0.1450, TP: 29, TN: 6, FP: 20, FN: 4
# Training model: StockLSTM
# Company: AMGN, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6894
# Company: AMGN, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6888
# Company: AMGN, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6887
# Company: AMGN, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6874
# Company: AMGN, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6885
# Company: AMGN, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6882
# Company: AMGN, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6875
# Company: AMGN, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6868
# Company: AMGN, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6863
# Company: AMGN, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6855
# Company: AMGN, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6840
# Company: AMGN, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6871
# Company: AMGN, Model: StockLSTM, Accuracy: 0.5593, MCC: 0.0000, TP: 33, TN: 0, FP: 26, FN: 0
# Training model: StockSentimentRNN
# Company: AMGN, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6894
# Company: AMGN, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6836
# Company: AMGN, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6811
# Company: AMGN, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6823
# Company: AMGN, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6743
# Company: AMGN, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6714
# Company: AMGN, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6699
# Company: AMGN, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6786
# Company: AMGN, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6688
# Company: AMGN, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6599
# Company: AMGN, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6780
# Company: AMGN, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6570
# Company: AMGN, Model: StockSentimentRNN, Accuracy: 0.5763, MCC: 0.1440, TP: 20, TN: 14, FP: 12, FN: 13
# Processing company: AMZN
# Training model: StockRNN
# Company: AMZN, Model: StockRNN, Epoch [10/120], Average Loss: 0.6868
# Company: AMZN, Model: StockRNN, Epoch [20/120], Average Loss: 0.6817
# Company: AMZN, Model: StockRNN, Epoch [30/120], Average Loss: 0.6799
# Company: AMZN, Model: StockRNN, Epoch [40/120], Average Loss: 0.6760
# Company: AMZN, Model: StockRNN, Epoch [50/120], Average Loss: 0.6898
# Company: AMZN, Model: StockRNN, Epoch [60/120], Average Loss: 0.6688
# Company: AMZN, Model: StockRNN, Epoch [70/120], Average Loss: 0.6673
# Company: AMZN, Model: StockRNN, Epoch [80/120], Average Loss: 0.6733
# Company: AMZN, Model: StockRNN, Epoch [90/120], Average Loss: 0.6625
# Company: AMZN, Model: StockRNN, Epoch [100/120], Average Loss: 0.6582
# Company: AMZN, Model: StockRNN, Epoch [110/120], Average Loss: 0.6548
# Company: AMZN, Model: StockRNN, Epoch [120/120], Average Loss: 0.6753
# Company: AMZN, Model: StockRNN, Accuracy: 0.4576, MCC: 0.0000, TP: 0, TN: 27, FP: 0, FN: 32
# Training model: StockLSTM
# Company: AMZN, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6916
# Company: AMZN, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6876
# Company: AMZN, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6836
# Company: AMZN, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6841
# Company: AMZN, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6816
# Company: AMZN, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6824
# Company: AMZN, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6915
# Company: AMZN, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6906
# Company: AMZN, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6897
# Company: AMZN, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6810
# Company: AMZN, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6858
# Company: AMZN, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6773
# Company: AMZN, Model: StockLSTM, Accuracy: 0.5424, MCC: 0.0000, TP: 32, TN: 0, FP: 27, FN: 0
# Training model: StockSentimentRNN
# Company: AMZN, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6896
# Company: AMZN, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6830
# Company: AMZN, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6810
# Company: AMZN, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6736
# Company: AMZN, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6952
# Company: AMZN, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6665
# Company: AMZN, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6636
# Company: AMZN, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6640
# Company: AMZN, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6528
# Company: AMZN, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6556
# Company: AMZN, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6531
# Company: AMZN, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6479
# Company: AMZN, Model: StockSentimentRNN, Accuracy: 0.4746, MCC: 0.1206, TP: 1, TN: 27, FP: 0, FN: 31
# Processing company: BA
# Training model: StockRNN
# Company: BA, Model: StockRNN, Epoch [10/120], Average Loss: 0.6914
# Company: BA, Model: StockRNN, Epoch [20/120], Average Loss: 0.6849
# Company: BA, Model: StockRNN, Epoch [30/120], Average Loss: 0.6836
# Company: BA, Model: StockRNN, Epoch [40/120], Average Loss: 0.6885
# Company: BA, Model: StockRNN, Epoch [50/120], Average Loss: 0.6806
# Company: BA, Model: StockRNN, Epoch [60/120], Average Loss: 0.6798
# Company: BA, Model: StockRNN, Epoch [70/120], Average Loss: 0.6788
# Company: BA, Model: StockRNN, Epoch [80/120], Average Loss: 0.6745
# Company: BA, Model: StockRNN, Epoch [90/120], Average Loss: 0.6668
# Company: BA, Model: StockRNN, Epoch [100/120], Average Loss: 0.6680
# Company: BA, Model: StockRNN, Epoch [110/120], Average Loss: 0.6676
# Company: BA, Model: StockRNN, Epoch [120/120], Average Loss: 0.6612
# Company: BA, Model: StockRNN, Accuracy: 0.5085, MCC: 0.0400, TP: 10, TN: 20, FP: 8, FN: 21
# Training model: StockLSTM
# Company: BA, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6876
# Company: BA, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6867
# Company: BA, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6838
# Company: BA, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6838
# Company: BA, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6829
# Company: BA, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6819
# Company: BA, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6803
# Company: BA, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6834
# Company: BA, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6803
# Company: BA, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6792
# Company: BA, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6800
# Company: BA, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6785
# Company: BA, Model: StockLSTM, Accuracy: 0.4915, MCC: 0.1248, TP: 1, TN: 28, FP: 0, FN: 30
# Training model: StockSentimentRNN
# Company: BA, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6861
# Company: BA, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6870
# Company: BA, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6884
# Company: BA, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6790
# Company: BA, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6819
# Company: BA, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6832
# Company: BA, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6748
# Company: BA, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6761
# Company: BA, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6791
# Company: BA, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6833
# Company: BA, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6699
# Company: BA, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6588
# Company: BA, Model: StockSentimentRNN, Accuracy: 0.5424, MCC: 0.1137, TP: 11, TN: 21, FP: 7, FN: 20
# Processing company: BABA
# Training model: StockRNN
# Company: BABA, Model: StockRNN, Epoch [10/120], Average Loss: 0.6904
# Company: BABA, Model: StockRNN, Epoch [20/120], Average Loss: 0.6861
# Company: BABA, Model: StockRNN, Epoch [30/120], Average Loss: 0.6870
# Company: BABA, Model: StockRNN, Epoch [40/120], Average Loss: 0.6840
# Company: BABA, Model: StockRNN, Epoch [50/120], Average Loss: 0.6741
# Company: BABA, Model: StockRNN, Epoch [60/120], Average Loss: 0.6725
# Company: BABA, Model: StockRNN, Epoch [70/120], Average Loss: 0.6651
# Company: BABA, Model: StockRNN, Epoch [80/120], Average Loss: 0.6623
# Company: BABA, Model: StockRNN, Epoch [90/120], Average Loss: 0.6586
# Company: BABA, Model: StockRNN, Epoch [100/120], Average Loss: 0.6658
# Company: BABA, Model: StockRNN, Epoch [110/120], Average Loss: 0.6630
# Company: BABA, Model: StockRNN, Epoch [120/120], Average Loss: 0.6718
# Company: BABA, Model: StockRNN, Accuracy: 0.5085, MCC: 0.0246, TP: 10, TN: 20, FP: 9, FN: 20
# Training model: StockLSTM
# Company: BABA, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6908
# Company: BABA, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6910
# Company: BABA, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6893
# Company: BABA, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6891
# Company: BABA, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6874
# Company: BABA, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6829
# Company: BABA, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6793
# Company: BABA, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6750
# Company: BABA, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6640
# Company: BABA, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6553
# Company: BABA, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6586
# Company: BABA, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6463
# Company: BABA, Model: StockLSTM, Accuracy: 0.4068, MCC: -0.1931, TP: 7, TN: 17, FP: 12, FN: 23
# Training model: StockSentimentRNN
# Company: BABA, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6883
# Company: BABA, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6926
# Company: BABA, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6898
# Company: BABA, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6885
# Company: BABA, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6825
# Company: BABA, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6696
# Company: BABA, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6727
# Company: BABA, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6738
# Company: BABA, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6659
# Company: BABA, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6572
# Company: BABA, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6653
# Company: BABA, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6612
# Company: BABA, Model: StockSentimentRNN, Accuracy: 0.5932, MCC: 0.1862, TP: 18, TN: 17, FP: 12, FN: 12
# Processing company: BAC
# Training model: StockRNN
# Company: BAC, Model: StockRNN, Epoch [10/120], Average Loss: 0.6874
# Company: BAC, Model: StockRNN, Epoch [20/120], Average Loss: 0.6800
# Company: BAC, Model: StockRNN, Epoch [30/120], Average Loss: 0.6792
# Company: BAC, Model: StockRNN, Epoch [40/120], Average Loss: 0.6693
# Company: BAC, Model: StockRNN, Epoch [50/120], Average Loss: 0.6801
# Company: BAC, Model: StockRNN, Epoch [60/120], Average Loss: 0.6759
# Company: BAC, Model: StockRNN, Epoch [70/120], Average Loss: 0.6710
# Company: BAC, Model: StockRNN, Epoch [80/120], Average Loss: 0.6710
# Company: BAC, Model: StockRNN, Epoch [90/120], Average Loss: 0.6653
# Company: BAC, Model: StockRNN, Epoch [100/120], Average Loss: 0.6511
# Company: BAC, Model: StockRNN, Epoch [110/120], Average Loss: 0.6587
# Company: BAC, Model: StockRNN, Epoch [120/120], Average Loss: 0.6732
# Company: BAC, Model: StockRNN, Accuracy: 0.6949, MCC: 0.3753, TP: 16, TN: 25, FP: 9, FN: 9
# Training model: StockLSTM
# Company: BAC, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6895
# Company: BAC, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6881
# Company: BAC, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6881
# Company: BAC, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6864
# Company: BAC, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6874
# Company: BAC, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6853
# Company: BAC, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6845
# Company: BAC, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6876
# Company: BAC, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6807
# Company: BAC, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6741
# Company: BAC, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6785
# Company: BAC, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6711
# Company: BAC, Model: StockLSTM, Accuracy: 0.6780, MCC: 0.3746, TP: 19, TN: 21, FP: 13, FN: 6
# Training model: StockSentimentRNN
# Company: BAC, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6861
# Company: BAC, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6872
# Company: BAC, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6771
# Company: BAC, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6763
# Company: BAC, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6748
# Company: BAC, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6696
# Company: BAC, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6633
# Company: BAC, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6600
# Company: BAC, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6665
# Company: BAC, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6552
# Company: BAC, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6532
# Company: BAC, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6606
# Company: BAC, Model: StockSentimentRNN, Accuracy: 0.6949, MCC: 0.3655, TP: 14, TN: 27, FP: 7, FN: 11
# Processing company: BBL
# Training model: StockRNN
# Company: BBL, Model: StockRNN, Epoch [10/120], Average Loss: 0.6904
# Company: BBL, Model: StockRNN, Epoch [20/120], Average Loss: 0.6843
# Company: BBL, Model: StockRNN, Epoch [30/120], Average Loss: 0.6872
# Company: BBL, Model: StockRNN, Epoch [40/120], Average Loss: 0.6737
# Company: BBL, Model: StockRNN, Epoch [50/120], Average Loss: 0.6758
# Company: BBL, Model: StockRNN, Epoch [60/120], Average Loss: 0.6663
# Company: BBL, Model: StockRNN, Epoch [70/120], Average Loss: 0.6569
# Company: BBL, Model: StockRNN, Epoch [80/120], Average Loss: 0.6572
# Company: BBL, Model: StockRNN, Epoch [90/120], Average Loss: 0.6451
# Company: BBL, Model: StockRNN, Epoch [100/120], Average Loss: 0.6417
# Company: BBL, Model: StockRNN, Epoch [110/120], Average Loss: 0.6432
# Company: BBL, Model: StockRNN, Epoch [120/120], Average Loss: 0.6423
# Company: BBL, Model: StockRNN, Accuracy: 0.4576, MCC: 0.1471, TP: 19, TN: 8, FP: 30, FN: 2
# Training model: StockLSTM
# Company: BBL, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6865
# Company: BBL, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6823
# Company: BBL, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6802
# Company: BBL, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6760
# Company: BBL, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6671
# Company: BBL, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6643
# Company: BBL, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6661
# Company: BBL, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6606
# Company: BBL, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6620
# Company: BBL, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6623
# Company: BBL, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6574
# Company: BBL, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6593
# Company: BBL, Model: StockLSTM, Accuracy: 0.3559, MCC: 0.0000, TP: 21, TN: 0, FP: 38, FN: 0
# Training model: StockSentimentRNN
# Company: BBL, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6878
# Company: BBL, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6818
# Company: BBL, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6791
# Company: BBL, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6763
# Company: BBL, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6665
# Company: BBL, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6630
# Company: BBL, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6693
# Company: BBL, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6510
# Company: BBL, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6547
# Company: BBL, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6494
# Company: BBL, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6354
# Company: BBL, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6233
# Company: BBL, Model: StockSentimentRNN, Accuracy: 0.5254, MCC: 0.2482, TP: 19, TN: 12, FP: 26, FN: 2
# Processing company: BCH
# Training model: StockRNN
# Company: BCH, Model: StockRNN, Epoch [10/120], Average Loss: 0.6913
# Company: BCH, Model: StockRNN, Epoch [20/120], Average Loss: 0.6915
# Company: BCH, Model: StockRNN, Epoch [30/120], Average Loss: 0.6847
# Company: BCH, Model: StockRNN, Epoch [40/120], Average Loss: 0.6848
# Company: BCH, Model: StockRNN, Epoch [50/120], Average Loss: 0.6881
# Company: BCH, Model: StockRNN, Epoch [60/120], Average Loss: 0.6804
# Company: BCH, Model: StockRNN, Epoch [70/120], Average Loss: 0.6816
# Company: BCH, Model: StockRNN, Epoch [80/120], Average Loss: 0.6776
# Company: BCH, Model: StockRNN, Epoch [90/120], Average Loss: 0.6772
# Company: BCH, Model: StockRNN, Epoch [100/120], Average Loss: 0.6791
# Company: BCH, Model: StockRNN, Epoch [110/120], Average Loss: 0.6754
# Company: BCH, Model: StockRNN, Epoch [120/120], Average Loss: 0.6752
# Company: BCH, Model: StockRNN, Accuracy: 0.5085, MCC: -0.0538, TP: 7, TN: 23, FP: 12, FN: 17
# Training model: StockLSTM
# Company: BCH, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6922
# Company: BCH, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6924
# Company: BCH, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6909
# Company: BCH, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6897
# Company: BCH, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6887
# Company: BCH, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6889
# Company: BCH, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6872
# Company: BCH, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6849
# Company: BCH, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6847
# Company: BCH, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6811
# Company: BCH, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6837
# Company: BCH, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6800
# Company: BCH, Model: StockLSTM, Accuracy: 0.5763, MCC: -0.1087, TP: 0, TN: 34, FP: 1, FN: 24
# Training model: StockSentimentRNN
# Company: BCH, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6922
# Company: BCH, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6935
# Company: BCH, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6871
# Company: BCH, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6887
# Company: BCH, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6823
# Company: BCH, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6779
# Company: BCH, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6772
# Company: BCH, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6761
# Company: BCH, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6739
# Company: BCH, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6791
# Company: BCH, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6727
# Company: BCH, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6741
# Company: BCH, Model: StockSentimentRNN, Accuracy: 0.5763, MCC: 0.0163, TP: 3, TN: 31, FP: 4, FN: 21
# Processing company: BHP
# Training model: StockRNN
# Company: BHP, Model: StockRNN, Epoch [10/120], Average Loss: 0.6923
# Company: BHP, Model: StockRNN, Epoch [20/120], Average Loss: 0.6929
# Company: BHP, Model: StockRNN, Epoch [30/120], Average Loss: 0.6939
# Company: BHP, Model: StockRNN, Epoch [40/120], Average Loss: 0.6888
# Company: BHP, Model: StockRNN, Epoch [50/120], Average Loss: 0.6876
# Company: BHP, Model: StockRNN, Epoch [60/120], Average Loss: 0.6901
# Company: BHP, Model: StockRNN, Epoch [70/120], Average Loss: 0.6850
# Company: BHP, Model: StockRNN, Epoch [80/120], Average Loss: 0.6858
# Company: BHP, Model: StockRNN, Epoch [90/120], Average Loss: 0.6892
# Company: BHP, Model: StockRNN, Epoch [100/120], Average Loss: 0.6856
# Company: BHP, Model: StockRNN, Epoch [110/120], Average Loss: 0.6835
# Company: BHP, Model: StockRNN, Epoch [120/120], Average Loss: 0.6809
# Company: BHP, Model: StockRNN, Accuracy: 0.4915, MCC: 0.1306, TP: 21, TN: 8, FP: 27, FN: 3
# Training model: StockLSTM
# Company: BHP, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6926
# Company: BHP, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6910
# Company: BHP, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6916
# Company: BHP, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6913
# Company: BHP, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6902
# Company: BHP, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6873
# Company: BHP, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6869
# Company: BHP, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6863
# Company: BHP, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6809
# Company: BHP, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6802
# Company: BHP, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6797
# Company: BHP, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6730
# Company: BHP, Model: StockLSTM, Accuracy: 0.4915, MCC: 0.1072, TP: 20, TN: 9, FP: 26, FN: 4
# Training model: StockSentimentRNN
# Company: BHP, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6923
# Company: BHP, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6893
# Company: BHP, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6903
# Company: BHP, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6864
# Company: BHP, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6851
# Company: BHP, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6841
# Company: BHP, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6864
# Company: BHP, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6813
# Company: BHP, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6762
# Company: BHP, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6896
# Company: BHP, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6759
# Company: BHP, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6727
# Company: BHP, Model: StockSentimentRNN, Accuracy: 0.5424, MCC: 0.2821, TP: 23, TN: 9, FP: 26, FN: 1
# Processing company: BP
# Training model: StockRNN
# Company: BP, Model: StockRNN, Epoch [10/120], Average Loss: 0.6885
# Company: BP, Model: StockRNN, Epoch [20/120], Average Loss: 0.6898
# Company: BP, Model: StockRNN, Epoch [30/120], Average Loss: 0.6892
# Company: BP, Model: StockRNN, Epoch [40/120], Average Loss: 0.6856
# Company: BP, Model: StockRNN, Epoch [50/120], Average Loss: 0.6868
# Company: BP, Model: StockRNN, Epoch [60/120], Average Loss: 0.6834
# Company: BP, Model: StockRNN, Epoch [70/120], Average Loss: 0.6827
# Company: BP, Model: StockRNN, Epoch [80/120], Average Loss: 0.6859
# Company: BP, Model: StockRNN, Epoch [90/120], Average Loss: 0.6850
# Company: BP, Model: StockRNN, Epoch [100/120], Average Loss: 0.6838
# Company: BP, Model: StockRNN, Epoch [110/120], Average Loss: 0.6844
# Company: BP, Model: StockRNN, Epoch [120/120], Average Loss: 0.6815
# Company: BP, Model: StockRNN, Accuracy: 0.5593, MCC: 0.0402, TP: 8, TN: 25, FP: 12, FN: 14
# Training model: StockLSTM
# Company: BP, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6903
# Company: BP, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6897
# Company: BP, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6902
# Company: BP, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6911
# Company: BP, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6898
# Company: BP, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6899
# Company: BP, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6896
# Company: BP, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6899
# Company: BP, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6882
# Company: BP, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6868
# Company: BP, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6875
# Company: BP, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6862
# Company: BP, Model: StockLSTM, Accuracy: 0.5593, MCC: -0.0182, TP: 5, TN: 28, FP: 9, FN: 17
# Training model: StockSentimentRNN
# Company: BP, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6920
# Company: BP, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6888
# Company: BP, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6888
# Company: BP, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6871
# Company: BP, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6854
# Company: BP, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6859
# Company: BP, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6866
# Company: BP, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6820
# Company: BP, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6849
# Company: BP, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6820
# Company: BP, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6849
# Company: BP, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6775
# Company: BP, Model: StockSentimentRNN, Accuracy: 0.5763, MCC: 0.0687, TP: 8, TN: 26, FP: 11, FN: 14
# Processing company: BRK-A
# Training model: StockRNN
# Company: BRK-A, Model: StockRNN, Epoch [10/120], Average Loss: 0.6904
# Company: BRK-A, Model: StockRNN, Epoch [20/120], Average Loss: 0.6896
# Company: BRK-A, Model: StockRNN, Epoch [30/120], Average Loss: 0.6863
# Company: BRK-A, Model: StockRNN, Epoch [40/120], Average Loss: 0.6834
# Company: BRK-A, Model: StockRNN, Epoch [50/120], Average Loss: 0.6822
# Company: BRK-A, Model: StockRNN, Epoch [60/120], Average Loss: 0.6843
# Company: BRK-A, Model: StockRNN, Epoch [70/120], Average Loss: 0.6814
# Company: BRK-A, Model: StockRNN, Epoch [80/120], Average Loss: 0.6830
# Company: BRK-A, Model: StockRNN, Epoch [90/120], Average Loss: 0.6849
# Company: BRK-A, Model: StockRNN, Epoch [100/120], Average Loss: 0.6800
# Company: BRK-A, Model: StockRNN, Epoch [110/120], Average Loss: 0.6799
# Company: BRK-A, Model: StockRNN, Epoch [120/120], Average Loss: 0.6794
# Company: BRK-A, Model: StockRNN, Accuracy: 0.4576, MCC: -0.1002, TP: 10, TN: 17, FP: 16, FN: 16
# Training model: StockLSTM
# Company: BRK-A, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6904
# Company: BRK-A, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6860
# Company: BRK-A, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6881
# Company: BRK-A, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6871
# Company: BRK-A, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6854
# Company: BRK-A, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6826
# Company: BRK-A, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6789
# Company: BRK-A, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6836
# Company: BRK-A, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6766
# Company: BRK-A, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6749
# Company: BRK-A, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6790
# Company: BRK-A, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6662
# Company: BRK-A, Model: StockLSTM, Accuracy: 0.4068, MCC: -0.1469, TP: 18, TN: 6, FP: 27, FN: 8
# Training model: StockSentimentRNN
# Company: BRK-A, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6893
# Company: BRK-A, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6854
# Company: BRK-A, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6839
# Company: BRK-A, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6806
# Company: BRK-A, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6847
# Company: BRK-A, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6733
# Company: BRK-A, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6783
# Company: BRK-A, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6756
# Company: BRK-A, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6814
# Company: BRK-A, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6684
# Company: BRK-A, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6730
# Company: BRK-A, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6665
# Company: BRK-A, Model: StockSentimentRNN, Accuracy: 0.3898, MCC: -0.1958, TP: 14, TN: 9, FP: 24, FN: 12
# Processing company: BSAC
# Training model: StockRNN
# Company: BSAC, Model: StockRNN, Epoch [10/120], Average Loss: 0.6906
# Company: BSAC, Model: StockRNN, Epoch [20/120], Average Loss: 0.6912
# Company: BSAC, Model: StockRNN, Epoch [30/120], Average Loss: 0.6874
# Company: BSAC, Model: StockRNN, Epoch [40/120], Average Loss: 0.6904
# Company: BSAC, Model: StockRNN, Epoch [50/120], Average Loss: 0.6914
# Company: BSAC, Model: StockRNN, Epoch [60/120], Average Loss: 0.6899
# Company: BSAC, Model: StockRNN, Epoch [70/120], Average Loss: 0.6879
# Company: BSAC, Model: StockRNN, Epoch [80/120], Average Loss: 0.6871
# Company: BSAC, Model: StockRNN, Epoch [90/120], Average Loss: 0.6834
# Company: BSAC, Model: StockRNN, Epoch [100/120], Average Loss: 0.6838
# Company: BSAC, Model: StockRNN, Epoch [110/120], Average Loss: 0.6862
# Company: BSAC, Model: StockRNN, Epoch [120/120], Average Loss: 0.6824
# Company: BSAC, Model: StockRNN, Accuracy: 0.5424, MCC: 0.2186, TP: 21, TN: 11, FP: 24, FN: 3
# Training model: StockLSTM
# Company: BSAC, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6907
# Company: BSAC, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6896
# Company: BSAC, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6879
# Company: BSAC, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6875
# Company: BSAC, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6870
# Company: BSAC, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6871
# Company: BSAC, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6862
# Company: BSAC, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6851
# Company: BSAC, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6814
# Company: BSAC, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6825
# Company: BSAC, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6836
# Company: BSAC, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6816
# Company: BSAC, Model: StockLSTM, Accuracy: 0.4407, MCC: 0.0861, TP: 23, TN: 3, FP: 32, FN: 1
# Training model: StockSentimentRNN
# Company: BSAC, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6898
# Company: BSAC, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6910
# Company: BSAC, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6895
# Company: BSAC, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6881
# Company: BSAC, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6908
# ...
# Company: UTX, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6931
# Company: UTX, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6759
# Company: UTX, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6675
# Company: UTX, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6678
# Company: UTX, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6645
# Company: UTX, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6675
# Company: UTX, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6585
# Company: UTX, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6584
# Company: UTX, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6591
# Company: UTX, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6601
# Company: UTX, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6616
# Company: UTX, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6566
# Company: UTX, Model: StockSentimentRNN, Accuracy: 0.4746, MCC: 0.0039, TP: 19, TN: 9, FP: 24, FN: 7
# Processing company: V
# Training model: StockRNN
# Company: V, Model: StockRNN, Epoch [10/120], Average Loss: 0.6908
# Company: V, Model: StockRNN, Epoch [20/120], Average Loss: 0.6897
# Company: V, Model: StockRNN, Epoch [30/120], Average Loss: 0.6883
# Company: V, Model: StockRNN, Epoch [40/120], Average Loss: 0.6844
# Company: V, Model: StockRNN, Epoch [50/120], Average Loss: 0.6881
# Company: V, Model: StockRNN, Epoch [60/120], Average Loss: 0.6856
# Company: V, Model: StockRNN, Epoch [70/120], Average Loss: 0.6849
# Company: V, Model: StockRNN, Epoch [80/120], Average Loss: 0.6841
# Company: V, Model: StockRNN, Epoch [90/120], Average Loss: 0.6847
# Company: V, Model: StockRNN, Epoch [100/120], Average Loss: 0.6774
# Company: V, Model: StockRNN, Epoch [110/120], Average Loss: 0.6828
# Company: V, Model: StockRNN, Epoch [120/120], Average Loss: 0.6832
# Company: V, Model: StockRNN, Accuracy: 0.5593, MCC: 0.1913, TP: 6, TN: 27, FP: 2, FN: 24
# Training model: StockLSTM
# Company: V, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6920
# Company: V, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6906
# Company: V, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6906
# Company: V, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6898
# Company: V, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6893
# Company: V, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6900
# Company: V, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6894
# Company: V, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6863
# Company: V, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6874
# Company: V, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6854
# Company: V, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6862
# Company: V, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6836
# Company: V, Model: StockLSTM, Accuracy: 0.4746, MCC: -0.1065, TP: 26, TN: 2, FP: 27, FN: 4
# Training model: StockSentimentRNN
# Company: V, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6957
# Company: V, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6940
# Company: V, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6876
# Company: V, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6843
# Company: V, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6871
# Company: V, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6839
# Company: V, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6849
# Company: V, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6893
# Company: V, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6768
# Company: V, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6802
# Company: V, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6761
# Company: V, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6804
# Company: V, Model: StockSentimentRNN, Accuracy: 0.5424, MCC: 0.1015, TP: 10, TN: 22, FP: 7, FN: 20
# Processing company: VZ
# Training model: StockRNN
# Company: VZ, Model: StockRNN, Epoch [10/120], Average Loss: 0.6843
# Company: VZ, Model: StockRNN, Epoch [20/120], Average Loss: 0.6872
# Company: VZ, Model: StockRNN, Epoch [30/120], Average Loss: 0.6824
# Company: VZ, Model: StockRNN, Epoch [40/120], Average Loss: 0.6804
# Company: VZ, Model: StockRNN, Epoch [50/120], Average Loss: 0.6766
# Company: VZ, Model: StockRNN, Epoch [60/120], Average Loss: 0.6757
# Company: VZ, Model: StockRNN, Epoch [70/120], Average Loss: 0.6727
# Company: VZ, Model: StockRNN, Epoch [80/120], Average Loss: 0.6765
# Company: VZ, Model: StockRNN, Epoch [90/120], Average Loss: 0.6664
# Company: VZ, Model: StockRNN, Epoch [100/120], Average Loss: 0.6655
# Company: VZ, Model: StockRNN, Epoch [110/120], Average Loss: 0.6798
# Company: VZ, Model: StockRNN, Epoch [120/120], Average Loss: 0.6561
# Company: VZ, Model: StockRNN, Accuracy: 0.5763, MCC: 0.1761, TP: 29, TN: 5, FP: 23, FN: 2
# Training model: StockLSTM
# Company: VZ, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6877
# Company: VZ, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6837
# Company: VZ, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6815
# Company: VZ, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6793
# Company: VZ, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6754
# Company: VZ, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6797
# Company: VZ, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6705
# Company: VZ, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6638
# Company: VZ, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6596
# Company: VZ, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6363
# Company: VZ, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6852
# Company: VZ, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6615
# Company: VZ, Model: StockLSTM, Accuracy: 0.6102, MCC: 0.2318, TP: 27, TN: 9, FP: 19, FN: 4
# Training model: StockSentimentRNN
# Company: VZ, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6864
# Company: VZ, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6836
# Company: VZ, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6821
# Company: VZ, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6803
# Company: VZ, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6809
# Company: VZ, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6680
# Company: VZ, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6683
# Company: VZ, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6689
# Company: VZ, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6754
# Company: VZ, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6611
# Company: VZ, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6589
# Company: VZ, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6687
# Company: VZ, Model: StockSentimentRNN, Accuracy: 0.5763, MCC: 0.1448, TP: 24, TN: 10, FP: 18, FN: 7
# Processing company: WFC
# Training model: StockRNN
# Company: WFC, Model: StockRNN, Epoch [10/120], Average Loss: 0.6843
# Company: WFC, Model: StockRNN, Epoch [20/120], Average Loss: 0.6775
# Company: WFC, Model: StockRNN, Epoch [30/120], Average Loss: 0.6732
# Company: WFC, Model: StockRNN, Epoch [40/120], Average Loss: 0.6756
# Company: WFC, Model: StockRNN, Epoch [50/120], Average Loss: 0.6745
# Company: WFC, Model: StockRNN, Epoch [60/120], Average Loss: 0.6695
# Company: WFC, Model: StockRNN, Epoch [70/120], Average Loss: 0.6729
# Company: WFC, Model: StockRNN, Epoch [80/120], Average Loss: 0.6696
# Company: WFC, Model: StockRNN, Epoch [90/120], Average Loss: 0.6625
# Company: WFC, Model: StockRNN, Epoch [100/120], Average Loss: 0.6752
# Company: WFC, Model: StockRNN, Epoch [110/120], Average Loss: 0.6528
# Company: WFC, Model: StockRNN, Epoch [120/120], Average Loss: 0.6597
# Company: WFC, Model: StockRNN, Accuracy: 0.5593, MCC: 0.1236, TP: 17, TN: 16, FP: 15, FN: 11
# Training model: StockLSTM
# Company: WFC, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6883
# Company: WFC, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6873
# Company: WFC, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6869
# Company: WFC, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6848
# Company: WFC, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6846
# Company: WFC, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6849
# Company: WFC, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6815
# Company: WFC, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6818
# Company: WFC, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6852
# Company: WFC, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6778
# Company: WFC, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6740
# Company: WFC, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6670
# Company: WFC, Model: StockLSTM, Accuracy: 0.5932, MCC: 0.1804, TP: 14, TN: 21, FP: 10, FN: 14
# Training model: StockSentimentRNN
# Company: WFC, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6882
# Company: WFC, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6839
# Company: WFC, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6773
# Company: WFC, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6753
# Company: WFC, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6707
# Company: WFC, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6723
# Company: WFC, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6661
# Company: WFC, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6753
# Company: WFC, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6640
# Company: WFC, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6583
# Company: WFC, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6611
# Company: WFC, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6668
# Company: WFC, Model: StockSentimentRNN, Accuracy: 0.5254, MCC: 0.0637, TP: 18, TN: 13, FP: 18, FN: 10
# Processing company: WMT
# Training model: StockRNN
# Company: WMT, Model: StockRNN, Epoch [10/120], Average Loss: 0.6929
# Company: WMT, Model: StockRNN, Epoch [20/120], Average Loss: 0.6940
# Company: WMT, Model: StockRNN, Epoch [30/120], Average Loss: 0.6916
# Company: WMT, Model: StockRNN, Epoch [40/120], Average Loss: 0.6902
# Company: WMT, Model: StockRNN, Epoch [50/120], Average Loss: 0.6835
# Company: WMT, Model: StockRNN, Epoch [60/120], Average Loss: 0.6841
# Company: WMT, Model: StockRNN, Epoch [70/120], Average Loss: 0.6829
# Company: WMT, Model: StockRNN, Epoch [80/120], Average Loss: 0.6841
# Company: WMT, Model: StockRNN, Epoch [90/120], Average Loss: 0.6805
# Company: WMT, Model: StockRNN, Epoch [100/120], Average Loss: 0.6807
# Company: WMT, Model: StockRNN, Epoch [110/120], Average Loss: 0.6815
# Company: WMT, Model: StockRNN, Epoch [120/120], Average Loss: 0.6800
# Company: WMT, Model: StockRNN, Accuracy: 0.5424, MCC: 0.0960, TP: 18, TN: 14, FP: 17, FN: 10
# Training model: StockLSTM
# Company: WMT, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6913
# Company: WMT, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6919
# Company: WMT, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6924
# Company: WMT, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6909
# Company: WMT, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6912
# Company: WMT, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6910
# Company: WMT, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6910
# Company: WMT, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6912
# Company: WMT, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6901
# Company: WMT, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6903
# Company: WMT, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6905
# Company: WMT, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6904
# Company: WMT, Model: StockLSTM, Accuracy: 0.4915, MCC: -0.0952, TP: 2, TN: 27, FP: 4, FN: 26
# Training model: StockSentimentRNN
# Company: WMT, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6935
# Company: WMT, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6930
# Company: WMT, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6915
# Company: WMT, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6923
# Company: WMT, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6860
# Company: WMT, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6850
# Company: WMT, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6838
# Company: WMT, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6833
# Company: WMT, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6846
# Company: WMT, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6812
# Company: WMT, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6824
# Company: WMT, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6823
# Company: WMT, Model: StockSentimentRNN, Accuracy: 0.5424, MCC: 0.0960, TP: 18, TN: 14, FP: 17, FN: 10
# Processing company: XOM
# Training model: StockRNN
# Company: XOM, Model: StockRNN, Epoch [10/120], Average Loss: 0.6905
# Company: XOM, Model: StockRNN, Epoch [20/120], Average Loss: 0.6844
# Company: XOM, Model: StockRNN, Epoch [30/120], Average Loss: 0.6821
# Company: XOM, Model: StockRNN, Epoch [40/120], Average Loss: 0.6796
# Company: XOM, Model: StockRNN, Epoch [50/120], Average Loss: 0.6812
# Company: XOM, Model: StockRNN, Epoch [60/120], Average Loss: 0.6803
# Company: XOM, Model: StockRNN, Epoch [70/120], Average Loss: 0.6757
# Company: XOM, Model: StockRNN, Epoch [80/120], Average Loss: 0.6735
# Company: XOM, Model: StockRNN, Epoch [90/120], Average Loss: 0.6750
# Company: XOM, Model: StockRNN, Epoch [100/120], Average Loss: 0.6768
# Company: XOM, Model: StockRNN, Epoch [110/120], Average Loss: 0.6699
# Company: XOM, Model: StockRNN, Epoch [120/120], Average Loss: 0.6700
# Company: XOM, Model: StockRNN, Accuracy: 0.5085, MCC: -0.1475, TP: 1, TN: 29, FP: 4, FN: 25
# Training model: StockLSTM
# Company: XOM, Model: StockLSTM, Epoch [10/120], Average Loss: 0.6882
# Company: XOM, Model: StockLSTM, Epoch [20/120], Average Loss: 0.6877
# Company: XOM, Model: StockLSTM, Epoch [30/120], Average Loss: 0.6874
# Company: XOM, Model: StockLSTM, Epoch [40/120], Average Loss: 0.6879
# Company: XOM, Model: StockLSTM, Epoch [50/120], Average Loss: 0.6861
# Company: XOM, Model: StockLSTM, Epoch [60/120], Average Loss: 0.6875
# Company: XOM, Model: StockLSTM, Epoch [70/120], Average Loss: 0.6866
# Company: XOM, Model: StockLSTM, Epoch [80/120], Average Loss: 0.6835
# Company: XOM, Model: StockLSTM, Epoch [90/120], Average Loss: 0.6816
# Company: XOM, Model: StockLSTM, Epoch [100/120], Average Loss: 0.6771
# Company: XOM, Model: StockLSTM, Epoch [110/120], Average Loss: 0.6724
# Company: XOM, Model: StockLSTM, Epoch [120/120], Average Loss: 0.6808
# Company: XOM, Model: StockLSTM, Accuracy: 0.5254, MCC: -0.0524, TP: 3, TN: 28, FP: 5, FN: 23
# Training model: StockSentimentRNN
# Company: XOM, Model: StockSentimentRNN, Epoch [10/120], Average Loss: 0.6883
# Company: XOM, Model: StockSentimentRNN, Epoch [20/120], Average Loss: 0.6844
# Company: XOM, Model: StockSentimentRNN, Epoch [30/120], Average Loss: 0.6840
# Company: XOM, Model: StockSentimentRNN, Epoch [40/120], Average Loss: 0.6796
# Company: XOM, Model: StockSentimentRNN, Epoch [50/120], Average Loss: 0.6786
# Company: XOM, Model: StockSentimentRNN, Epoch [60/120], Average Loss: 0.6775
# Company: XOM, Model: StockSentimentRNN, Epoch [70/120], Average Loss: 0.6822
# Company: XOM, Model: StockSentimentRNN, Epoch [80/120], Average Loss: 0.6778
# Company: XOM, Model: StockSentimentRNN, Epoch [90/120], Average Loss: 0.6750
# Company: XOM, Model: StockSentimentRNN, Epoch [100/120], Average Loss: 0.6736
# Company: XOM, Model: StockSentimentRNN, Epoch [110/120], Average Loss: 0.6732
# Company: XOM, Model: StockSentimentRNN, Epoch [120/120], Average Loss: 0.6730
# Company: XOM, Model: StockSentimentRNN, Accuracy: 0.4576, MCC: -0.2190, TP: 2, TN: 25, FP: 8, FN: 24
# Evaluation complete
#                    Average Accuracy  Average MACC
# StockRNN                   0.513540      0.041600
# StockLSTM                  0.515878      0.035293
# StockSentimentRNN          0.515293      0.051124
